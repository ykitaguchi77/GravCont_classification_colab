# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/GravCont_classification_colab/blob/master/ResNet50_nonpretrained_adabound_crossvalidation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**GravCont: EfficientNet_b4_ImageNet**
# ValidationとTestに分けて解析

# %%
from __future__ import print_function, division
# !pip install torch_optimizer

import torch
import torch.nn as nn
import torch_optimizer as optim
import torch.utils.data as data
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import math
import shutil

#Advanced Pytorchから
import glob
import os.path as osp
import random
import json
from PIL import Image
from tqdm import tqdm
# %matplotlib inline

import pandas as pd

#サポートパッチのインポート
from google.colab.patches import cv2_imshow
import cv2

plt.ion()   # interactive mode
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Set random seem for reproducibility
manualSeed = 1234
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.cuda.manual_seed(manualSeed)

torch.torch.backends.cudnn.benchmark = True
torch.torch.backends.cudnn.enabled = True

# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet 

import numpy as np
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


'''
grav: 甲状腺眼症
cont: コントロール
黒の空白を挿入することにより225px*225pxの画像を生成、EfficientNetを用いて転移学習
－－－－－－－－－－－－－－
データの構造
gravcont.zip ------grav
               |---cont
'''                                     

#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Requirement already satisfied: torch_optimizer in /usr/local/lib/python3.6/dist-packages (0.0.1a15)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from torch_optimizer) (0.1.1)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from torch_optimizer) (1.6.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.1.0->torch_optimizer) (0.16.0)
# Random Seed:  1234
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet_pytorch) (1.6.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (1.18.5)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**モジュール群**

# %%
def pre_process(data_dir):
    # 入力画像の前処理をするクラス
    # 訓練時と推論時で処理が異なる

    """
        画像の前処理クラス。訓練時、検証時で異なる動作をする。
        画像のサイズをリサイズし、色を標準化する。
        訓練時はRandomResizedCropとRandomHorizontalFlipでデータオーギュメンテーションする。


        Attributes
        ----------
        resize : int
            リサイズ先の画像の大きさ。
        mean : (R, G, B)
            各色チャネルの平均値。
        std : (R, G, B)
            各色チャネルの標準偏差。
    """

    data_transforms = {
        'train': transforms.Compose([
            transforms.RandomResizedCrop(224, scale=(0.75,1.0)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'val': transforms.Compose([
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

    data_dir = data_dir
    n_samples = len(data_dir)

    image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                              data_transforms[x])
                      for x in ['train', 'val']}
    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=20,
                                                shuffle=True, num_workers=4)
                  for x in ['train', 'val']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
    class_names = image_datasets['train'].classes


    print(class_names)
    k=0
    for i in class_names:
        print(class_names[k]+"_train:"+str(len(os.listdir(path=data_dir + '/train/'+class_names[k]))))
        k+=1
    k=0
    for i in class_names:
        print(class_names[k]+"_val:"+str(len(os.listdir(path=data_dir + '/val/'+class_names[k]))))
        k+=1

    print("training data set_total："+ str(len(image_datasets['train'])))
    print("validating data set_total："+str(len(image_datasets['val'])))
    
    return image_datasets, dataloaders, dataset_sizes, class_names, device


#少数の画像を可視化
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


def getBatch(dataloaders):    
    # Get a batch of training data
    inputs, classes = next(iter(dataloaders['train']))

    # Make a grid from batch
    out = torchvision.utils.make_grid(inputs)

    #imshow(out, title=[class_names[x] for x in classes])
    return(inputs, classes)

#Defining early stopping class
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss


#Train models
def train_model(model, criterion, optimizer, patience, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    # to track the training loss as the model trains
    train_loss = []
    # to track the validation loss as the model trains
    valid_loss = []


    # initialize the early_stopping object
    early_stopping = EarlyStopping(patience=patience, verbose=True)

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase] 
            
            # record train_loss and valid_loss
            if phase == 'train':
                train_loss.append(epoch_loss)
            if phase == 'val':
                valid_loss.append(epoch_loss)
            #print(train_loss)
            #print(valid_loss)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))


            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
      
      # early_stopping needs the validation loss to check if it has decresed, 
      # and if it has, it will make a checkpoint of the current model
        if phase == 'val':    
            early_stopping(epoch_loss, model)
                
            if early_stopping.early_stop:
                print("Early stopping")
                break
        print()


    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, train_loss, valid_loss


#Visualize model
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)


def training(model_ft, criterion, optimizer_ft,  patience=15, num_epochs=50):
    model_ft, train_loss, valid_loss = train_model(model_ft, criterion, optimizer_ft,  patience=patience, num_epochs=num_epochs)


#対象のパスからラベルを抜き出して表示
def getlabel(image_path):
      image_name = os.path.basename(image_path)
      label = os.path.basename(os.path.dirname(image_path))
      return(image_name, label)

'''
#変形後の画像を表示
def image_transform(image_path):

    image=Image.open(image_path)

    
    #変形した画像を表示する
    transform = transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224)])
    image_transformed = transform(image)
    plt.imshow(np.array(image_transformed))
'''

#評価のための画像下処理
def image_transform(image_path):    
    image=Image.open(image_path)
    transform = transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
    image_tensor = transform(image)

    #バッチサイズの次元を先頭に追加した4Dテンソルに変換
    image_tensor.unsqueeze_(0)
    #print(image_tensor.size())  # torch.Size([1, 3, 224, 224])
    image_tensor = image_tensor.to(device) #model_ftをGPUに載せる

    return(image_tensor)

#モデルにした処理した画像を投入して予測結果を表示
def image_eval(image_tensor, label):
    output = model_ft(image_tensor)
    #print(output.size())  # torch.Size([1, 1000])
    #print(output)

    #model_pred:クラス名前、prob:確率、pred:クラス番号
    prob, pred = torch.topk(nn.Softmax(dim=1)(output), 1)
    model_pred = class_names[pred]
    
    #甲状腺眼症のprobabilityを計算（classが0なら1から減算、classが1ならそのまま）
    prob = abs(1-float(prob)-float(pred))
 
    return model_pred, prob, pred

    """
    #probalilityを計算する
    pred_prob = torch.topk(nn.Softmax(dim=1)(output), 1)[0]
    pred_class = torch.topk(nn.Softmax(dim=1)(output), 1)[1]
    if pred_class == 1:
        pred_prob = pred_prob
    elif pred_class == 0:
        pred_prob = 1- pred_prob
    return(model_pred, pred_prob)  #class_nameの番号で出力される
    """

def showImage(image_path):
    #画像のインポート
    img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
    #画像のリサイズ
    height = img.shape[0]
    width = img.shape[1]
    resized_img = cv2.resize(img, (int(width*300/height), 300))
    cv2_imshow(resized_img)

def calculateAccuracy (TP, TN, FP, FN):
    accuracy = (TP + TN)/ (TP + TN + FP + FN)
    precision  = TP/(FP + TP)
    recall = TP/(TP + FN)
    specificity = TN/(FP + TN)
    f_value = (2*recall*precision)/(recall+precision)
    return(accuracy, precision, recall, specificity, f_value)

"""
・True positive (TN)
・False positive (FP)
・True negative (TN)
・False negative (FN)
Accuracy = (TP + TN)/ (TP + TN + FP + FN)
Precision = TP/(FP + TP) ※positive predictive value
Recall = TP/(TP + FN)　※sensitivity
Specificity = TN/(FP + TN)
F_value = (2RecallPrecision)/(Recall+Precision)
"""

def evaluation(model_ft, testset_dir):
    #評価モードにする
    model_ft.eval()

    #testデータセット内のファイル名を取得
    image_path = glob.glob(testset_dir + "/*/*")
    #random.shuffle(image_path)  #表示順をランダムにする
    print('number of images: ' +str(len(image_path)))


    TP, FP, TN, FN, TP, FP, TN, FN = [0,0,0,0,0,0,0,0]
    image_name_list = []
    label_list = []
    model_pred_list = []
    hum_pred_list = []

    model_pred_class = []
    model_pred_prob = []

    for i in image_path:
          image_name, label = getlabel(i)  #画像の名前とラベルを取得
          image_tensor = image_transform(i)  #予測のための画像下処理
          model_pred, prob, pred = image_eval(image_tensor, label)  #予測結果を出力   
          #print('Image: '+ image_name)
          #print('Label: '+ label)
          #print('Pred: '+ model_pred)
          #showImage(i)  #画像を表示
          #print() #空白行を入れる
          time.sleep(0.1)

          image_name_list.append(image_name)
          label_list.append(label)
          model_pred_list.append(model_pred)

          model_pred_class.append(int(pred))
          model_pred_prob.append(float(prob))

          if label == class_names[0]:
              if model_pred == class_names[0]:
                  TN += 1
              else:
                  FP += 1
          elif label == class_names[1]:
              if model_pred == class_names[1]:
                  TP += 1
              else:
                  FN += 1     

    print(TP, FN, TN, FP)

    #Accuracyを計算
    accuracy, precision, recall, specificity, f_value = calculateAccuracy (TP, TN, FP, FN)
    print('Accuracy: ' + str(accuracy))
    print('Precision (positive predictive value): ' + str(precision))
    print('Recall (sensitivity): ' + str(recall))
    print('Specificity: ' + str(specificity))
    print('F_value: ' + str(f_value))

    #print(model_pred_class)
    #print(model_pred_prob)

    return TP,TN,FP,FN, accuracy, precision, recall, specificity, f_value, label_list, model_pred_prob


def make_csv(roc_label_list):
    #csvのdata tableを作成
    pd.set_option('display.max_rows', 800)  # 省略なしで表示
    #columns1 = ["EfficientNet_32", "EfficientNet_64", "EfficientNet_128", "EfficientNet_256", "EfficientNet_512", "EfficientNet_558"]
    roc_label_list.extend(["avg", "std"])
    index1 = ["TP","TN","FP","FN","Accuracy","Positive predictive value","sensitity","specificity","F-value","roc_auc"]
    df = pd.DataFrame(index=index1, columns=roc_label_list)
    return df

def write_csv(df, col, TP, TN, FP, FN, accuracy, precision, recall, specificity, f_value,roc_auc):
    df.iloc[0:10, col] = TP, TN, FP, FN, accuracy, precision, recall, specificity, f_value,roc_auc 
    #print(df)

    # CSVとして出力
    #df2.to_csv("/content/drive/My Drive/Grav_bootcamp/Posttrain_model_eval_result.csv",encoding="shift_jis")
    return df

def Draw_roc_curve(label_list_list, model_pred_prob_list, sample_num_list, num_curves):

#グラフの外形を作成
    fig = plt.figure(figsize=(8.0, 6.0))
    lw = 2
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    ycolor = ["r", "g", "b", "c", "m", "y", "k", "w"]      # 各プロットの色
    plt.legend(loc="lower right")

    k=0
    for j in range(num_curves):
        y_score = []
        y_true = []

        for i in label_list_list[k]:
            if i == 'cont':
                  y_true.append(0)
            elif i == 'grav':
                  y_true.append(1)
            
        #それぞれの画像における陽性の確率についてリストを作成
        y_score = model_pred_prob_list[k]

        fpr, tpr,thred = roc_curve(y_true, y_score)
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, color=ycolor[k],lw=lw, label= str(roc_label_list[k])+':ROC curve (area = %0.2f)' % roc_auc)
            
        k+=1

    plt.legend(loc="lower right")
    plt.show()
    return fig

def calculate_auc(label_list, model_pred_prob):
    y_true, y_score = [], []
    for i in label_list:
        if i == 'cont':
              y_true.append(0)
        elif i == 'grav':
              y_true.append(1)
            
    #それぞれの画像における陽性の確率についてリストを作成
    y_score = model_pred_prob
    fpr, tpr,thred = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)
    print("roc_auc: " +str(roc_auc))
    return(roc_auc, y_true, y_score)

def calcurate_ave_std(df, fold):
    for i in range(5):
        df.iloc[i,fold] = df[i,0:5].mean 

def convnet():
    model_ft = models.resnet50(pretrained=False)
    num_ftrs = model_ft.fc.in_features
    model_ft.fc = nn.Linear(num_ftrs, 2)

    #GPU使用
    model_ft = model_ft.to(device)

    #損失関数を定義
    criterion = nn.CrossEntropyLoss()

    # Observe that all parameters are being optimized
    #https://blog.knjcode.com/adabound-memo/
    #https://pypi.org/project/torch-optimizer/
    optimizer_ft = optim.AdaBound(
        model_ft.parameters(),
        lr= 1e-3,
        betas= (0.9, 0.999),
        final_lr = 0.1,
        gamma=1e-3,
        eps= 1e-8,
        weight_decay=0,
        amsbound=False,
    )
    return (model_ft, criterion, optimizer_ft)

# %% [markdown]
# #**まとめて解析**

# %%
#create data_dir_list
data_dir = '/content/drive/My Drive/gravcont_crossvalidation'
fold = len(os.listdir(data_dir))
print(fold)

data_dir_list = [0]*fold

for i in range(fold):
    data_dir_list[i] = data_dir + '/' + str(i)
    print(data_dir_list[i])

#create roc_label_list
roc_label_list = [0]*fold
roc_label_list = list(range(fold))
print(roc_label_list)
# Out:
# 5
# /content/drive/My Drive/gravcont_crossvalidation/0
# /content/drive/My Drive/gravcont_crossvalidation/1
# /content/drive/My Drive/gravcont_crossvalidation/2
# /content/drive/My Drive/gravcont_crossvalidation/3
# /content/drive/My Drive/gravcont_crossvalidation/4
# [0, 1, 2, 3, 4]

# %%
df = make_csv(roc_label_list)

label_list_list, model_pred_prob_list, Y_TRUE, Y_SCORE = [],[],[],[]

print(data_dir_list)
print(roc_label_list)

for i, t in enumerate(zip(data_dir_list, roc_label_list)):

    image_datasets, dataloaders, dataset_sizes, class_names, device = pre_process(t[0]) #path
    inputs, classes = getBatch(dataloaders)
    model_ft, criterion, optimizer_ft = convnet()
    training(model_ft, criterion, optimizer_ft,  patience=15, num_epochs=50)  
    TP,TN,FP,FN, accuracy, precision, recall, specificity, f_value, label_list, model_pred_prob = evaluation(model_ft, '/content/drive/My Drive/Grav_bootcamp/Posttrain_250px')
    roc_auc, y_true, y_score = calculate_auc(label_list, model_pred_prob)
    Y_TRUE.append(y_true)
    Y_SCORE.append(y_score)
    df = write_csv(df, i,TP,TN,FP,FN, accuracy, precision, recall, specificity, f_value, roc_auc) #numberをcsvの行として指定

    label_list_list.append(label_list)
    model_pred_prob_list.append(model_pred_prob)
    print("")
    print("")

#Draw ROC curve
fig = Draw_roc_curve(label_list_list, model_pred_prob_list, roc_label_list, len(label_list_list))

pd.set_option('display.max_columns', 100)
#それぞれの項目の平均を計算しcsvに追記する
df.iloc[0:4,fold], df.iloc[9,fold]   = df.mean(axis=1)[0:4], df.mean(axis=1)[9] 
df.iloc[0:10,fold+1] = df.std(axis=1)[0:10]
TP,TN,FP,FN = df.mean(axis=1)[0:4]
df.iloc[4:9,fold] = calculateAccuracy (TP, TN, FP, FN)
print(df)

# 出力名を記入
out_name = "ResNet50_nonpretrained_256"

# CSVとして出力
df.to_csv("/content/drive/My Drive/Grav_bootcamp/crossvaridation_" + out_name + ".csv",encoding="shift_jis")

#ROC_curveを保存
fig.savefig("/content/drive/My Drive/Grav_bootcamp/crossvaridation_" + out_name +".png")
# Out:
# ['/content/drive/My Drive/gravcont_crossvalidation/0', '/content/drive/My Drive/gravcont_crossvalidation/1', '/content/drive/My Drive/gravcont_crossvalidation/2', '/content/drive/My Drive/gravcont_crossvalidation/3', '/content/drive/My Drive/gravcont_crossvalidation/4']
# [0, 1, 2, 3, 4, 'avg', 'std']
# ['cont', 'grav']
# cont_train:102
# grav_train:102
# cont_val:26
# grav_val:26
# training data set_total：204
# validating data set_total：52
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b4-6ed6700e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b4-6ed6700e.pth
# HBox(children=(FloatProgress(value=0.0, max=77999237.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b4
# Epoch 0/49
# ----------
# /usr/local/lib/python3.6/dist-packages/torch_optimizer/adabound.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   exp_avg.mul_(beta1).add_(1 - beta1, grad)
# train Loss: 0.6241 Acc: 0.6324
# val Loss: 0.7478 Acc: 0.5577
# Validation loss decreased (inf --> 0.747778).  Saving model ...
#
# Epoch 1/49
# ----------
# train Loss: 0.3769 Acc: 0.8480
# val Loss: 1.1506 Acc: 0.6731
# EarlyStopping counter: 1 out of 15
#
# Epoch 2/49
# ----------
# train Loss: 0.3833 Acc: 0.8284
# val Loss: 0.8993 Acc: 0.7115
# EarlyStopping counter: 2 out of 15
#
# Epoch 3/49
# ----------
# train Loss: 0.3385 Acc: 0.8284
# val Loss: 1.2013 Acc: 0.7115
# EarlyStopping counter: 3 out of 15
#
# Epoch 4/49
# ----------
# train Loss: 0.2498 Acc: 0.8873
# val Loss: 1.1654 Acc: 0.7308
# EarlyStopping counter: 4 out of 15
#
# Epoch 5/49
# ----------
# train Loss: 0.2158 Acc: 0.9265
# val Loss: 3.1565 Acc: 0.7115
# EarlyStopping counter: 5 out of 15
#
# Epoch 6/49
# ----------
# train Loss: 0.1981 Acc: 0.9020
# val Loss: 4.1776 Acc: 0.5962
# EarlyStopping counter: 6 out of 15
#
# Epoch 7/49
# ----------
# train Loss: 0.1625 Acc: 0.9559
# val Loss: 1.9370 Acc: 0.7308
# EarlyStopping counter: 7 out of 15
#
# Epoch 8/49
# ----------
# train Loss: 0.1039 Acc: 0.9657
# val Loss: 0.8337 Acc: 0.8269
# EarlyStopping counter: 8 out of 15
#
# Epoch 9/49
# ----------
# train Loss: 0.1570 Acc: 0.9363
# val Loss: 1.3992 Acc: 0.7500
# EarlyStopping counter: 9 out of 15
#
# Epoch 10/49
# ----------
# train Loss: 0.1047 Acc: 0.9755
# val Loss: 2.3088 Acc: 0.7885
# EarlyStopping counter: 10 out of 15
#
# Epoch 11/49
# ----------
# train Loss: 0.1533 Acc: 0.9706
# val Loss: 1.0023 Acc: 0.8269
# EarlyStopping counter: 11 out of 15
#
# Epoch 12/49
# ----------
# train Loss: 0.0766 Acc: 0.9853
# val Loss: 0.7798 Acc: 0.7692
# EarlyStopping counter: 12 out of 15
#
# Epoch 13/49
# ----------
# train Loss: 0.2249 Acc: 0.9069
# val Loss: 0.6159 Acc: 0.7692
# Validation loss decreased (0.747778 --> 0.615852).  Saving model ...
#
# Epoch 14/49
# ----------
# train Loss: 0.1419 Acc: 0.9804
# val Loss: 0.5305 Acc: 0.8077
# Validation loss decreased (0.615852 --> 0.530540).  Saving model ...
#
# Epoch 15/49
# ----------
# train Loss: 0.1151 Acc: 0.9657
# val Loss: 0.5368 Acc: 0.8269
# EarlyStopping counter: 1 out of 15
#
# Epoch 16/49
# ----------
# train Loss: 0.0688 Acc: 0.9804
# val Loss: 0.6180 Acc: 0.8269
# EarlyStopping counter: 2 out of 15
#
# Epoch 17/49
# ----------
# train Loss: 0.0818 Acc: 0.9755
# val Loss: 0.9140 Acc: 0.7308
# EarlyStopping counter: 3 out of 15
#
# Epoch 18/49
# ----------
# train Loss: 0.0969 Acc: 0.9706
# val Loss: 1.3877 Acc: 0.7308
# EarlyStopping counter: 4 out of 15
#
# Epoch 19/49
# ----------
# train Loss: 0.0746 Acc: 0.9804
# val Loss: 1.2889 Acc: 0.7308
# EarlyStopping counter: 5 out of 15
#
# Epoch 20/49
# ----------
# train Loss: 0.0646 Acc: 0.9755
# val Loss: 1.2315 Acc: 0.7308
# EarlyStopping counter: 6 out of 15
#
# Epoch 21/49
# ----------
# train Loss: 0.0416 Acc: 0.9804
# val Loss: 2.1789 Acc: 0.7115
# EarlyStopping counter: 7 out of 15
#
# Epoch 22/49
# ----------
# train Loss: 0.0469 Acc: 0.9755
# val Loss: 1.5322 Acc: 0.7500
# EarlyStopping counter: 8 out of 15
#
# Epoch 23/49
# ----------
# train Loss: 0.0324 Acc: 0.9902
# val Loss: 1.4672 Acc: 0.7500
# EarlyStopping counter: 9 out of 15
#
# Epoch 24/49
# ----------
# train Loss: 0.0120 Acc: 1.0000
# val Loss: 1.3144 Acc: 0.7500
# EarlyStopping counter: 10 out of 15
#
# Epoch 25/49
# ----------
# train Loss: 0.0680 Acc: 0.9706
# val Loss: 1.3624 Acc: 0.7885
# EarlyStopping counter: 11 out of 15
#
# Epoch 26/49
# ----------
# train Loss: 0.1424 Acc: 0.9559
# val Loss: 0.5901 Acc: 0.8462
# EarlyStopping counter: 12 out of 15
#
# Epoch 27/49
# ----------
# train Loss: 0.1788 Acc: 0.9167
# val Loss: 0.4144 Acc: 0.8462
# Validation loss decreased (0.530540 --> 0.414417).  Saving model ...
#
# Epoch 28/49
# ----------
# train Loss: 0.1437 Acc: 0.9559
# val Loss: 0.5859 Acc: 0.8077
# EarlyStopping counter: 1 out of 15
#
# Epoch 29/49
# ----------
# train Loss: 0.0988 Acc: 0.9608
# val Loss: 0.5161 Acc: 0.7885
# EarlyStopping counter: 2 out of 15
#
# Epoch 30/49
# ----------
# train Loss: 0.1075 Acc: 0.9706
# val Loss: 0.5119 Acc: 0.8269
# EarlyStopping counter: 3 out of 15
#
# Epoch 31/49
# ----------
# train Loss: 0.1028 Acc: 0.9608
# val Loss: 0.4356 Acc: 0.8462
# EarlyStopping counter: 4 out of 15
#
# Epoch 32/49
# ----------
# train Loss: 0.1022 Acc: 0.9755
# val Loss: 0.5064 Acc: 0.7885
# EarlyStopping counter: 5 out of 15
#
# Epoch 33/49
# ----------
# train Loss: 0.0458 Acc: 0.9853
# val Loss: 0.5594 Acc: 0.8077
# EarlyStopping counter: 6 out of 15
#
# Epoch 34/49
# ----------
# train Loss: 0.0103 Acc: 1.0000
# val Loss: 0.5414 Acc: 0.8269
# EarlyStopping counter: 7 out of 15
#
# Epoch 35/49
# ----------
# train Loss: 0.0729 Acc: 0.9853
# val Loss: 0.5347 Acc: 0.8269
# EarlyStopping counter: 8 out of 15
#
# Epoch 36/49
# ----------
# train Loss: 0.0164 Acc: 1.0000
# val Loss: 0.4598 Acc: 0.8269
# EarlyStopping counter: 9 out of 15
#
# Epoch 37/49
# ----------
# train Loss: 0.0224 Acc: 1.0000
# val Loss: 0.4816 Acc: 0.8269
# EarlyStopping counter: 10 out of 15
#
# Epoch 38/49
# ----------
# train Loss: 0.0312 Acc: 0.9853
# val Loss: 0.7143 Acc: 0.7885
# EarlyStopping counter: 11 out of 15
#
# Epoch 39/49
# ----------
# train Loss: 0.0898 Acc: 0.9804
# val Loss: 0.6057 Acc: 0.8462
# EarlyStopping counter: 12 out of 15
#
# Epoch 40/49
# ----------
# train Loss: 0.0292 Acc: 0.9853
# val Loss: 0.5024 Acc: 0.8269
# EarlyStopping counter: 13 out of 15
#
# Epoch 41/49
# ----------
# train Loss: 0.0535 Acc: 0.9853
# val Loss: 0.4441 Acc: 0.8462
# EarlyStopping counter: 14 out of 15
#
# Epoch 42/49
# ----------
# train Loss: 0.0361 Acc: 0.9804
# val Loss: 0.5526 Acc: 0.8269
# EarlyStopping counter: 15 out of 15
# Early stopping
# Training complete in 4m 35s
# Best val Acc: 0.846154
# number of images: 108
# 34 20 53 1
# Accuracy: 0.8055555555555556
# Precision (positive predictive value): 0.9714285714285714
# Recall (sensitivity): 0.6296296296296297
# Specificity: 0.9814814814814815
# F_value: 0.7640449438202247
# roc_auc: 0.8659122085048011
#
#
# ['cont', 'grav']
# cont_train:102
# grav_train:135
# cont_val:26
# grav_val:26
# training data set_total：237
# validating data set_total：52
# Loaded pretrained weights for efficientnet-b4
# Epoch 0/49
# ----------
# train Loss: 0.5924 Acc: 0.7046
# val Loss: 0.5261 Acc: 0.6731
# Validation loss decreased (inf --> 0.526072).  Saving model ...
#
# Epoch 1/49
# ----------
# train Loss: 0.4197 Acc: 0.8439
# val Loss: 0.2837 Acc: 0.9038
# Validation loss decreased (0.526072 --> 0.283719).  Saving model ...
#
# Epoch 2/49
# ----------
# train Loss: 0.2708 Acc: 0.8987
# val Loss: 1.0112 Acc: 0.7692
# EarlyStopping counter: 1 out of 15
#
# Epoch 3/49
# ----------
# train Loss: 0.2125 Acc: 0.9325
# val Loss: 0.7003 Acc: 0.8462
# EarlyStopping counter: 2 out of 15
#
# Epoch 4/49
# ----------
# train Loss: 0.1989 Acc: 0.9283
# val Loss: 1.1473 Acc: 0.7500
# EarlyStopping counter: 3 out of 15
#
# Epoch 5/49
# ----------
# train Loss: 0.1085 Acc: 0.9705
# val Loss: 0.4478 Acc: 0.9231
# EarlyStopping counter: 4 out of 15
#
# Epoch 6/49
# ----------
# train Loss: 0.1142 Acc: 0.9662
# val Loss: 0.3543 Acc: 0.9038
# EarlyStopping counter: 5 out of 15
#
# Epoch 7/49
# ----------
# train Loss: 0.1969 Acc: 0.9494
# val Loss: 1.8445 Acc: 0.7885
# EarlyStopping counter: 6 out of 15
#
# Epoch 8/49
# ----------
# train Loss: 0.1572 Acc: 0.9409
# val Loss: 1.0025 Acc: 0.8269
# EarlyStopping counter: 7 out of 15
#
# Epoch 9/49
# ----------
# train Loss: 0.0876 Acc: 0.9789
# val Loss: 0.4494 Acc: 0.8462
# EarlyStopping counter: 8 out of 15
#
# Epoch 10/49
# ----------
# train Loss: 0.1080 Acc: 0.9705
# val Loss: 0.9697 Acc: 0.8269
# EarlyStopping counter: 9 out of 15
#
# Epoch 11/49
# ----------
# train Loss: 0.0704 Acc: 0.9747
# val Loss: 0.5661 Acc: 0.8269
# EarlyStopping counter: 10 out of 15
#
# Epoch 12/49
# ----------
# train Loss: 0.0464 Acc: 0.9831
# val Loss: 0.9453 Acc: 0.8462
# EarlyStopping counter: 11 out of 15
#
# Epoch 13/49
# ----------
# train Loss: 0.0674 Acc: 0.9831
# val Loss: 0.5718 Acc: 0.8654
# EarlyStopping counter: 12 out of 15
#
# Epoch 14/49
# ----------
# train Loss: 0.1056 Acc: 0.9620
# val Loss: 0.5013 Acc: 0.8462
# EarlyStopping counter: 13 out of 15
#
# Epoch 15/49
# ----------
# train Loss: 0.0406 Acc: 0.9958
# val Loss: 0.7376 Acc: 0.8462
# EarlyStopping counter: 14 out of 15
#
# Epoch 16/49
# ----------
# train Loss: 0.0172 Acc: 0.9958
# val Loss: 0.7260 Acc: 0.8269
# EarlyStopping counter: 15 out of 15
# Early stopping
# Training complete in 2m 4s
# Best val Acc: 0.923077
# number of images: 108
# 43 11 45 9
# Accuracy: 0.8148148148148148
# Precision (positive predictive value): 0.8269230769230769
# Recall (sensitivity): 0.7962962962962963
# Specificity: 0.8333333333333334
# F_value: 0.8113207547169811
# roc_auc: 0.861111111111111
#
#
# ['cont', 'grav']
# cont_train:120
# grav_train:249
# cont_val:26
# grav_val:76
# training data set_total：369
# validating data set_total：102
# Loaded pretrained weights for efficientnet-b4
# Epoch 0/49
# ----------
# train Loss: 0.5789 Acc: 0.7100
# val Loss: 0.5792 Acc: 0.7451
# Validation loss decreased (inf --> 0.579180).  Saving model ...
#
# Epoch 1/49
# ----------
# train Loss: 0.4248 Acc: 0.8238
# val Loss: 0.5989 Acc: 0.8333
# EarlyStopping counter: 1 out of 15
#
# Epoch 2/49
# ----------
# train Loss: 0.2851 Acc: 0.8835
# val Loss: 1.5669 Acc: 0.7745
# EarlyStopping counter: 2 out of 15
#
# Epoch 3/49
# ----------
# train Loss: 0.2750 Acc: 0.8780
# val Loss: 0.9459 Acc: 0.8039
# EarlyStopping counter: 3 out of 15
#
# Epoch 4/49
# ----------
# train Loss: 0.2884 Acc: 0.8699
# val Loss: 0.5709 Acc: 0.8431
# Validation loss decreased (0.579180 --> 0.570946).  Saving model ...
#
# Epoch 5/49
# ----------
# train Loss: 0.1615 Acc: 0.9431
# val Loss: 0.3788 Acc: 0.8824
# Validation loss decreased (0.570946 --> 0.378762).  Saving model ...
#
# Epoch 6/49
# ----------
# train Loss: 0.1074 Acc: 0.9648
# val Loss: 0.6573 Acc: 0.8627
# EarlyStopping counter: 1 out of 15
#
# Epoch 7/49
# ----------
# train Loss: 0.1696 Acc: 0.9431
# val Loss: 0.3199 Acc: 0.8627
# Validation loss decreased (0.378762 --> 0.319888).  Saving model ...
#
# Epoch 8/49
# ----------
# train Loss: 0.2028 Acc: 0.9133
# val Loss: 0.3053 Acc: 0.9020
# Validation loss decreased (0.319888 --> 0.305315).  Saving model ...
#
# Epoch 9/49
# ----------
# train Loss: 0.0764 Acc: 0.9892
# val Loss: 0.3257 Acc: 0.8922
# EarlyStopping counter: 1 out of 15
#
# Epoch 10/49
# ----------
# train Loss: 0.0587 Acc: 0.9756
# val Loss: 0.3197 Acc: 0.9118
# EarlyStopping counter: 2 out of 15
#
# Epoch 11/49
# ----------
# train Loss: 0.1071 Acc: 0.9621
# val Loss: 1.0283 Acc: 0.7549
# EarlyStopping counter: 3 out of 15
#
# Epoch 12/49
# ----------
# train Loss: 0.1199 Acc: 0.9648
# val Loss: 0.3171 Acc: 0.8922
# EarlyStopping counter: 4 out of 15
#
# Epoch 13/49
# ----------
# train Loss: 0.0625 Acc: 0.9783
# val Loss: 0.2414 Acc: 0.9118
# Validation loss decreased (0.305315 --> 0.241351).  Saving model ...
#
# Epoch 14/49
# ----------
# train Loss: 0.0348 Acc: 0.9864
# val Loss: 0.2657 Acc: 0.9020
# EarlyStopping counter: 1 out of 15
#
# Epoch 15/49
# ----------
# train Loss: 0.0168 Acc: 0.9973
# val Loss: 0.3395 Acc: 0.9118
# EarlyStopping counter: 2 out of 15
#
# Epoch 16/49
# ----------
# train Loss: 0.0269 Acc: 0.9946
# val Loss: 0.4680 Acc: 0.8725
# EarlyStopping counter: 3 out of 15
#
# Epoch 17/49
# ----------
# train Loss: 0.0087 Acc: 0.9973
# val Loss: 0.2876 Acc: 0.9118
# EarlyStopping counter: 4 out of 15
#
# Epoch 18/49
# ----------
# train Loss: 0.0352 Acc: 0.9864
# val Loss: 0.2369 Acc: 0.9216
# Validation loss decreased (0.241351 --> 0.236864).  Saving model ...
#
# Epoch 19/49
# ----------
# train Loss: 0.0264 Acc: 0.9892
# val Loss: 0.2679 Acc: 0.9020
# EarlyStopping counter: 1 out of 15
#
# Epoch 20/49
# ----------
# train Loss: 0.0156 Acc: 0.9946
# val Loss: 0.2831 Acc: 0.9020
# EarlyStopping counter: 2 out of 15
#
# Epoch 21/49
# ----------
# train Loss: 0.0207 Acc: 0.9973
# val Loss: 0.3026 Acc: 0.9118
# EarlyStopping counter: 3 out of 15
#
# Epoch 22/49
# ----------
# train Loss: 0.0221 Acc: 0.9973
# val Loss: 0.2769 Acc: 0.9020
# EarlyStopping counter: 4 out of 15
#
# Epoch 23/49
# ----------
# train Loss: 0.0223 Acc: 0.9892
# val Loss: 0.2411 Acc: 0.9020
# EarlyStopping counter: 5 out of 15
#
# Epoch 24/49
# ----------
# train Loss: 0.0106 Acc: 0.9973
# val Loss: 0.2975 Acc: 0.8725
# EarlyStopping counter: 6 out of 15
#
# Epoch 25/49
# ----------
# train Loss: 0.0090 Acc: 0.9973
# val Loss: 0.3567 Acc: 0.8725
# EarlyStopping counter: 7 out of 15
#
# Epoch 26/49
# ----------
# train Loss: 0.0063 Acc: 0.9973
# val Loss: 0.3573 Acc: 0.8824
# EarlyStopping counter: 8 out of 15
#
# Epoch 27/49
# ----------
# train Loss: 0.0100 Acc: 0.9973
# val Loss: 0.5868 Acc: 0.8725
# EarlyStopping counter: 9 out of 15
#
# Epoch 28/49
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.3476 Acc: 0.8922
# EarlyStopping counter: 10 out of 15
#
# Epoch 29/49
# ----------
# train Loss: 0.0038 Acc: 0.9973
# val Loss: 0.3291 Acc: 0.8824
# EarlyStopping counter: 11 out of 15
#
# Epoch 30/49
# ----------
# train Loss: 0.0050 Acc: 0.9973
# val Loss: 0.3476 Acc: 0.8725
# EarlyStopping counter: 12 out of 15
#
# Epoch 31/49
# ----------
# train Loss: 0.0036 Acc: 1.0000
# val Loss: 0.3026 Acc: 0.8824
# EarlyStopping counter: 13 out of 15
#
# Epoch 32/49
# ----------
# train Loss: 0.0035 Acc: 1.0000
# val Loss: 0.3058 Acc: 0.9216
# EarlyStopping counter: 14 out of 15
#
# Epoch 33/49
# ----------
# train Loss: 0.0357 Acc: 0.9919
# val Loss: 0.4857 Acc: 0.9020
# EarlyStopping counter: 15 out of 15
# Early stopping
# Training complete in 6m 9s
# Best val Acc: 0.921569
# number of images: 108
# 44 10 40 14
# Accuracy: 0.7777777777777778
# Precision (positive predictive value): 0.7586206896551724
# Recall (sensitivity): 0.8148148148148148
# Specificity: 0.7407407407407407
# F_value: 0.7857142857142857
# roc_auc: 0.8954046639231824
#
#
# ['cont', 'grav']
# cont_train:243
# grav_train:247
# cont_val:76
# grav_val:77
# training data set_total：490
# validating data set_total：153
# Loaded pretrained weights for efficientnet-b4
# Epoch 0/49
# ----------
# train Loss: 0.5823 Acc: 0.7061
# val Loss: 0.6203 Acc: 0.7255
# Validation loss decreased (inf --> 0.620336).  Saving model ...
#
# Epoch 1/49
# ----------
# train Loss: 0.4499 Acc: 0.7980
# val Loss: 1.1168 Acc: 0.7255
# EarlyStopping counter: 1 out of 15
#
# Epoch 2/49
# ----------
# train Loss: 0.2592 Acc: 0.8837
# val Loss: 1.1610 Acc: 0.6797
# EarlyStopping counter: 2 out of 15
#
# Epoch 3/49
# ----------
# train Loss: 0.2876 Acc: 0.8837
# val Loss: 0.6902 Acc: 0.7582
# EarlyStopping counter: 3 out of 15
#
# Epoch 4/49
# ----------
# train Loss: 0.2283 Acc: 0.9061
# val Loss: 0.4391 Acc: 0.9216
# Validation loss decreased (0.620336 --> 0.439109).  Saving model ...
#
# Epoch 5/49
# ----------
# train Loss: 0.1673 Acc: 0.9327
# val Loss: 0.4564 Acc: 0.9020
# EarlyStopping counter: 1 out of 15
#
# Epoch 6/49
# ----------
# train Loss: 0.1077 Acc: 0.9592
# val Loss: 0.3968 Acc: 0.9150
# Validation loss decreased (0.439109 --> 0.396832).  Saving model ...
#
# Epoch 7/49
# ----------
# train Loss: 0.1530 Acc: 0.9510
# val Loss: 0.8045 Acc: 0.8170
# EarlyStopping counter: 1 out of 15
#
# Epoch 8/49
# ----------
# train Loss: 0.1166 Acc: 0.9592
# val Loss: 0.3795 Acc: 0.8889
# Validation loss decreased (0.396832 --> 0.379476).  Saving model ...
#
# Epoch 9/49
# ----------
# train Loss: 0.0968 Acc: 0.9735
# val Loss: 0.2866 Acc: 0.9085
# Validation loss decreased (0.379476 --> 0.286613).  Saving model ...
#
# Epoch 10/49
# ----------
# train Loss: 0.0821 Acc: 0.9653
# val Loss: 0.4075 Acc: 0.9085
# EarlyStopping counter: 1 out of 15
#
# Epoch 11/49
# ----------
# train Loss: 0.0741 Acc: 0.9714
# val Loss: 0.3290 Acc: 0.9346
# EarlyStopping counter: 2 out of 15
#
# Epoch 12/49
# ----------
# train Loss: 0.0714 Acc: 0.9714
# val Loss: 0.4260 Acc: 0.8954
# EarlyStopping counter: 3 out of 15
#
# Epoch 13/49
# ----------
# train Loss: 0.0341 Acc: 0.9898
# val Loss: 0.6118 Acc: 0.8889
# EarlyStopping counter: 4 out of 15
#
# Epoch 14/49
# ----------
# train Loss: 0.0256 Acc: 0.9918
# val Loss: 0.3887 Acc: 0.9281
# EarlyStopping counter: 5 out of 15
#
# Epoch 15/49
# ----------
# train Loss: 0.0171 Acc: 0.9939
# val Loss: 0.3610 Acc: 0.9281
# EarlyStopping counter: 6 out of 15
#
# Epoch 16/49
# ----------
# train Loss: 0.0203 Acc: 0.9939
# val Loss: 0.4986 Acc: 0.9085
# EarlyStopping counter: 7 out of 15
#
# Epoch 17/49
# ----------
# train Loss: 0.0539 Acc: 0.9878
# val Loss: 0.6675 Acc: 0.8366
# EarlyStopping counter: 8 out of 15
#
# Epoch 18/49
# ----------
# train Loss: 0.0541 Acc: 0.9837
# val Loss: 0.4332 Acc: 0.8824
# EarlyStopping counter: 9 out of 15
#
# Epoch 19/49
# ----------
# train Loss: 0.0490 Acc: 0.9796
# val Loss: 0.3874 Acc: 0.9020
# EarlyStopping counter: 10 out of 15
#
# Epoch 20/49
# ----------
# train Loss: 0.0358 Acc: 0.9898
# val Loss: 0.3399 Acc: 0.8954
# EarlyStopping counter: 11 out of 15
#
# Epoch 21/49
# ----------
# train Loss: 0.0420 Acc: 0.9837
# val Loss: 0.2890 Acc: 0.9150
# EarlyStopping counter: 12 out of 15
#
# Epoch 22/49
# ----------
# train Loss: 0.0234 Acc: 0.9959
# val Loss: 0.2957 Acc: 0.9216
# EarlyStopping counter: 13 out of 15
#
# Epoch 23/49
# ----------
# train Loss: 0.0146 Acc: 0.9980
# val Loss: 0.3040 Acc: 0.9150
# EarlyStopping counter: 14 out of 15
#
# Epoch 24/49
# ----------
# train Loss: 0.0037 Acc: 1.0000
# val Loss: 0.3441 Acc: 0.9216
# EarlyStopping counter: 15 out of 15
# Early stopping
# Training complete in 5m 54s
# Best val Acc: 0.934641
# number of images: 108
# 43 11 47 7
# Accuracy: 0.8333333333333334
# Precision (positive predictive value): 0.86
# Recall (sensitivity): 0.7962962962962963
# Specificity: 0.8703703703703703
# F_value: 0.826923076923077
# roc_auc: 0.9128943758573388
#
#
# ['cont', 'grav']
# cont_train:254
# grav_train:248
# cont_val:93
# grav_val:90
# training data set_total：502
# validating data set_total：183
# Loaded pretrained weights for efficientnet-b4
# Epoch 0/49
# ----------
# train Loss: 0.6261 Acc: 0.6693
# val Loss: 0.5130 Acc: 0.7596
# Validation loss decreased (inf --> 0.513042).  Saving model ...
#
# Epoch 1/49
# ----------
# train Loss: 0.4085 Acc: 0.8367
# val Loss: 0.2355 Acc: 0.9180
# Validation loss decreased (0.513042 --> 0.235471).  Saving model ...
#
# Epoch 2/49
# ----------
# train Loss: 0.2861 Acc: 0.8984
# val Loss: 0.4036 Acc: 0.9016
# EarlyStopping counter: 1 out of 15
#
# Epoch 3/49
# ----------
# train Loss: 0.2506 Acc: 0.9064
# val Loss: 1.0786 Acc: 0.7814
# EarlyStopping counter: 2 out of 15
#
# Epoch 4/49
# ----------
# train Loss: 0.3198 Acc: 0.8606
# val Loss: 0.4130 Acc: 0.8798
# EarlyStopping counter: 3 out of 15
#
# Epoch 5/49
# ----------
# train Loss: 0.1567 Acc: 0.9363
# val Loss: 0.2164 Acc: 0.9344
# Validation loss decreased (0.235471 --> 0.216399).  Saving model ...
#
# Epoch 6/49
# ----------
# train Loss: 0.1988 Acc: 0.9402
# val Loss: 1.3506 Acc: 0.7650
# EarlyStopping counter: 1 out of 15
#
# Epoch 7/49
# ----------
# train Loss: 0.1685 Acc: 0.9303
# val Loss: 0.1489 Acc: 0.9399
# Validation loss decreased (0.216399 --> 0.148889).  Saving model ...
#
# Epoch 8/49
# ----------
# train Loss: 0.0907 Acc: 0.9761
# val Loss: 0.1830 Acc: 0.9454
# EarlyStopping counter: 1 out of 15
#
# Epoch 9/49
# ----------
# train Loss: 0.0830 Acc: 0.9761
# val Loss: 0.1480 Acc: 0.9454
# Validation loss decreased (0.148889 --> 0.147988).  Saving model ...
#
# Epoch 10/49
# ----------
# train Loss: 0.0652 Acc: 0.9781
# val Loss: 0.2974 Acc: 0.9399
# EarlyStopping counter: 1 out of 15
#
# Epoch 11/49
# ----------
# train Loss: 0.0361 Acc: 0.9900
# val Loss: 0.1740 Acc: 0.9454
# EarlyStopping counter: 2 out of 15
#
# Epoch 12/49
# ----------
# train Loss: 0.0437 Acc: 0.9880
# val Loss: 0.1029 Acc: 0.9563
# Validation loss decreased (0.147988 --> 0.102901).  Saving model ...
#
# Epoch 13/49
# ----------
# train Loss: 0.0458 Acc: 0.9781
# val Loss: 0.1431 Acc: 0.9672
# EarlyStopping counter: 1 out of 15
#
# Epoch 14/49
# ----------
# train Loss: 0.0561 Acc: 0.9821
# val Loss: 0.2072 Acc: 0.9399
# EarlyStopping counter: 2 out of 15
#
# Epoch 15/49
# ----------
# train Loss: 0.1198 Acc: 0.9582
# val Loss: 0.1587 Acc: 0.9344
# EarlyStopping counter: 3 out of 15
#
# Epoch 16/49
# ----------
# train Loss: 0.1446 Acc: 0.9562
# val Loss: 0.6062 Acc: 0.7978
# EarlyStopping counter: 4 out of 15
#
# Epoch 17/49
# ----------
# train Loss: 0.0895 Acc: 0.9681
# val Loss: 0.3395 Acc: 0.8798
# EarlyStopping counter: 5 out of 15
#
# Epoch 18/49
# ----------
# train Loss: 0.1214 Acc: 0.9522
# val Loss: 0.3686 Acc: 0.8361
# EarlyStopping counter: 6 out of 15
#
# Epoch 19/49
# ----------
# train Loss: 0.0747 Acc: 0.9681
# val Loss: 0.1391 Acc: 0.9399
# EarlyStopping counter: 7 out of 15
#
# Epoch 20/49
# ----------
# train Loss: 0.0297 Acc: 0.9880
# val Loss: 0.1448 Acc: 0.9508
# EarlyStopping counter: 8 out of 15
#
# Epoch 21/49
# ----------
# train Loss: 0.0095 Acc: 1.0000
# val Loss: 0.0827 Acc: 0.9672
# Validation loss decreased (0.102901 --> 0.082689).  Saving model ...
#
# Epoch 22/49
# ----------
# train Loss: 0.0214 Acc: 0.9960
# val Loss: 0.1581 Acc: 0.9617
# EarlyStopping counter: 1 out of 15
#
# Epoch 23/49
# ----------
# train Loss: 0.0648 Acc: 0.9781
# val Loss: 0.2427 Acc: 0.9235
# EarlyStopping counter: 2 out of 15
#
# Epoch 24/49
# ----------
# train Loss: 0.0350 Acc: 0.9861
# val Loss: 0.2948 Acc: 0.9180
# EarlyStopping counter: 3 out of 15
#
# Epoch 25/49
# ----------
# train Loss: 0.0429 Acc: 0.9900
# val Loss: 0.1409 Acc: 0.9617
# EarlyStopping counter: 4 out of 15
#
# Epoch 26/49
# ----------
# train Loss: 0.1219 Acc: 0.9602
# val Loss: 0.2715 Acc: 0.8852
# EarlyStopping counter: 5 out of 15
#
# Epoch 27/49
# ----------
# train Loss: 0.1227 Acc: 0.9582
# val Loss: 0.1816 Acc: 0.9344
# EarlyStopping counter: 6 out of 15
#
# Epoch 28/49
# ----------
# train Loss: 0.0439 Acc: 0.9880
# val Loss: 0.1730 Acc: 0.9290
# EarlyStopping counter: 7 out of 15
#
# Epoch 29/49
# ----------
# train Loss: 0.0397 Acc: 0.9880
# val Loss: 0.1264 Acc: 0.9563
# EarlyStopping counter: 8 out of 15
#
# Epoch 30/49
# ----------
# train Loss: 0.0366 Acc: 0.9900
# val Loss: 0.1270 Acc: 0.9617
# EarlyStopping counter: 9 out of 15
#
# Epoch 31/49
# ----------
# train Loss: 0.0503 Acc: 0.9841
# val Loss: 0.1444 Acc: 0.9290
# EarlyStopping counter: 10 out of 15
#
# Epoch 32/49
# ----------
# train Loss: 0.0407 Acc: 0.9821
# val Loss: 0.1291 Acc: 0.9508
# EarlyStopping counter: 11 out of 15
#
# Epoch 33/49
# ----------
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f302d1f96d8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1101, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1075, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 124, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.6/multiprocessing/popen_fork.py", line 47, in wait
#     if not wait([self.sentinel], timeout):
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cd7bdf8e1196> in <module>()
#      11     inputs, classes = getBatch(dataloaders)
#      12     model_ft, criterion, optimizer_ft = convnet()
# ---> 13     training(model_ft, criterion, optimizer_ft,  patience=15, num_epochs=50)
#      14     TP,TN,FP,FN, accuracy, precision, recall, specificity, f_value, label_list, model_pred_prob = evaluation(model_ft, '/content/drive/My Drive/Grav_bootcamp/Posttrain_250px')
#      15     roc_auc, y_true, y_score = calculate_auc(label_list, model_pred_prob)
#
# <ipython-input-5-069bf01d784a> in training(model_ft, criterion, optimizer_ft, patience, num_epochs)
#     285
#     286 def training(model_ft, criterion, optimizer_ft,  patience=15, num_epochs=50):
# --> 287     model_ft, train_loss, valid_loss = train_model(model_ft, criterion, optimizer_ft,  patience=patience, num_epochs=num_epochs)
#     288
#     289
#
# <ipython-input-5-069bf01d784a> in train_model(model, criterion, optimizer, patience, num_epochs)
#     183                     if phase == 'train':
#     184                         loss.backward()
# --> 185                         optimizer.step()
#     186
#     187                 # statistics
#
# /usr/local/lib/python3.6/dist-packages/torch_optimizer/adabound.py in step(self, closure)
#     141                 # Decay the first and second moment running average coefficient
#     142                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# --> 143                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#     144                 if amsbound:
#     145                     # Maintains the maximum of all 2nd moment running
#
# KeyboardInterrupt:

# %%
import csv
#Save ROC data
with open("/content/drive/My Drive/Grav_bootcamp/ROCdata_"+out_name+".csv", 'w') as f:
    writer = csv.writer(f)
    for i, t in enumerate(zip(Y_TRUE, Y_SCORE)):
        writer.writerow([t[0],t[1]])

# %% [markdown]
# #**ネットワークの保存と読み込み**

# %%
#ネットワークの保存
PATH = '/content/drive/My Drive/Grav_bootcamp/GravCont_EfficientNet-b4_ImageNet_seed'+str(manualSeed)+'.pth'
torch.save(model_ft.state_dict(), PATH)

# %%
#ネットワークの読み込み
PATH = '/content/drive/My Drive/Grav_bootcamp/GravCont_EfficientNet-b4_ImageNet_seed'+str(manualSeed)+'.pth'
torch.save(model_ft.state_dict(), PATH)
model_ft.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>
