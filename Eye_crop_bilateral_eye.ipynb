# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/GravCont_classification_colab/blob/master/Eye_crop_bilateral_eye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #顔の画像から目を検出して切り抜くスクリプト
# ・Haarcascade_eyeを使用<br>
# ・目が検出できないものはskipする<br>
# ・横幅を1/4倍、縦幅を上下に1/4倍追加して画像を切り取る（目の全幅、眉毛が含まれるように）
#
# ・切り取った画像を500px*500pxにresizeする<br>
# ・フォルダ内の画像を一括変換して別フォルダに保存

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import shutil
import copy
import pandas as pd
import csv
from random import randint
from time import sleep
import numpy as np
import sys


import glob
import random
from PIL import Image
# %matplotlib inline

#サポートパッチのインポート
from google.colab.patches import cv2_imshow
import cv2

plt.ion()   # interactive mode

# %% [markdown]
# #Google colabをマウント

# %%
'''
・dlibを用いて目を切り抜く
・横幅を2倍、縦幅を上に1倍追加/下に0.5倍追加して画像を切り取る（目の全幅、眉毛が含まれるように）
'''

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#残り時間確認
# !cat /proc/uptime | awk '{printf("残り時間 : %.2f", 12-$1/60/60)}'
# Out:
# 残り時間 : 11.63

# %%
#元画像
in_path = '/content/drive/MyDrive/Deep_learning/Face_Images/IMG_3110.JPG'

#保存先フォルダ
out_path = '/content/drive/My Drive/Deep_learning/eyelid_images/IMG_3110_eye.JPG'

# %% [markdown]
# #Haarcascadeを指定

# %%
# カスケードファイルのパス
eye_cascade_path = '/content/drive/My Drive/Deep_learning/haarcascade_eye.xml'

# カスケード分類器の特徴量取得
eye_cascade = cv2.CascadeClassifier(eye_cascade_path)

# %%
#アスペクト比を維持したまま横を400pixelに縮小する
def scale_to_width(img, width):
    scale = width / img.shape[1]
    return cv2.resize(img, dsize=None, fx=scale, fy=scale)

#図を表示する
def show_image(img):
    #img = cv2.imread(out_path)
    dst = scale_to_width(img, 100)
    cv2_imshow(dst)

def my_round(val, digit=0):
    p = 10 ** digit
    return int((val * p * 2 + 1) // 2 / p)

# %%
def crop_bilateral(in_path, size):
    img_resized_list,side_list = [],[]

    img = cv2.imread(in_path) 
    img2 = img.copy()

    # 画像グレースケール化
    grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    #300pix以上のもので目に見えるものを抽出
    eye_list = eye_cascade.detectMultiScale(grayscale_img, minSize=(300, 300))
    print('image path = ',in_path)

    # 眼検出判定
    if len(eye_list) >= 1:
        print('目が' + str(len(eye_list)) +'個検出されました')
        pass
    else:
        print("no eye detected")
        pass

    print(eye_list)

    #画像の切り抜きと保存（連番にする）
    if len(eye_list)>= 1: 
        for (ex, ey, ew, eh) in eye_list:
            print("[ex,ey] = %d,%d [ew,eh] = %d,%d" %(ex, ey, ew, eh))
            
            try:
              cv2.rectangle(img2, (ex, ey), (ex + ew, ey + eh), (0, 255, 0), 2)

              #切り抜き範囲が元画像をはみ出る場合は黒画像で埋める
              top = max(0, ey)
              bottom = min(grayscale_img.shape[0], int(ey + eh))
              left = max(0,int(ex))
              right = min(grayscale_img.shape[1], int(ex + ew))
              # top = max(0, ey)
              # bottom = min(grayscale_img.shape[0], int(ey))
              # left = max(0,int(ex))
              # right = min(grayscale_img.shape[1], int(ex))

              #print(f"top:{top}, bottom:{bottom}, left:{left}, right:{right}")

              img_cropped = img[top: bottom,left:right]
              height, width = img_cropped.shape[:2]


              #print(f"height:{height}, width:{width}")
              if width==height:
                  img_background =img_cropped
              elif width>height:
                  img_background = np.zeros((width,width,3), dtype = np.uint8)
                  img_background[0:width, my_round(int((width-height)/2)) :int(((width+height)/2)+height)]=img_cropped
              elif width<height:
                  img_background = np.zeros((height,height,3), dtype = np.uint8)
                  img_background[0:height, my_round(int((width-height)/2)) :int(((height-width)/2)+width)]=img_cropped
              
              img_resized = cv2.resize(img_background,(size,size)) #1辺を指定したpixにresize 

              #show_image(img_resized)

            except:
              print('crop error')

            if ex <= grayscale_img.shape[1]/2:
                side = 0 #600ピクセル目より左にあるのは右眼
            else:
                side = 1 #600ピクセル目より右にあるのは左眼

            try:
                img_resized_list.append(img_resized)
                side_list.append(side)
            except:
                pass

    return(img_resized_list, side_list)

# %%
img_resized_list, side_list = crop_bilateral(in_path, 500)

#検出された画像を確認
src = cv2.cvtColor(img_resized_list[0], cv2.COLOR_BGR2RGB)
plt.imshow(src)
# Out:
# image path =  /content/drive/MyDrive/Deep_learning/Face_Images/IMG_3110.JPG
# 目が2個検出されました
# [[1247 1189  436  436]
#  [ 596 1278  424  424]]
# [ex,ey] = 1247,1189 [ew,eh] = 436,436
# [ex,ey] = 596,1278 [ew,eh] = 424,424

# %% [markdown]
# #**ここからがメイン**

# %%
orig_folder = "/content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset" #olympiaのデータセット
path_list = glob.glob(orig_folder+"/*")
path = path_list[0]
path
# Out:
# '/content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/19.JPG'

# %%
orig_folder = "/content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset" #olympiaのデータセット
dst_folder = "/content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset_250px_uni_eye"


#処理時間の計測
start = time.time()

#もしdst_folderがあれば削除して新しく作り直す
if os.path.exists(dst_folder):
    shutil.rmtree(dst_folder)
os.makedirs(dst_folder)

path_list = glob.glob(orig_folder+"/*")

for path in path_list:
    img_resized_list, side_list = crop_bilateral(path, 250) #両眼抜き出して224pxで保存（crop時にエラーが出るものは削除される）
    for img, side in zip(img_resized_list, side_list):
        if side == 0:
            sidestr = "R"
        elif side == 1:
            sidestr = "L"
        cv2.imwrite(dst_folder +"/"+ os.path.basename(path).split(".")[0]+"_"+sidestr+".JPG", img)

print('Process done!!')
elapsed_time = time.time() - start
print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# [ex,ey] = 1486,525 [ew,eh] = 886,886
# [ex,ey] = 115,513 [ew,eh] = 794,794
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/948.JPG
# 目が2個検出されました
# [[ 212  540  750  750]
#  [1650  621  697  697]]
# [ex,ey] = 212,540 [ew,eh] = 750,750
# [ex,ey] = 1650,621 [ew,eh] = 697,697
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/179.JPG
# 目が2個検出されました
# [[ 135  554  825  825]
#  [1632  556  750  750]]
# [ex,ey] = 135,554 [ew,eh] = 825,825
# [ex,ey] = 1632,556 [ew,eh] = 750,750
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/949.JPG
# 目が2個検出されました
# [[ 156  579  720  720]
#  [1581  539  779  779]]
# [ex,ey] = 156,579 [ew,eh] = 720,720
# [ex,ey] = 1581,539 [ew,eh] = 779,779
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/180.JPG
# 目が2個検出されました
# [[1586  508  871  871]
#  [  68  534  858  858]]
# [ex,ey] = 1586,508 [ew,eh] = 871,871
# [ex,ey] = 68,534 [ew,eh] = 858,858
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/210.JPG
# 目が2個検出されました
# [[1602  605  741  741]
#  [ 182  493  728  728]]
# [ex,ey] = 1602,605 [ew,eh] = 741,741
# [ex,ey] = 182,493 [ew,eh] = 728,728
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/209.JPG
# 目が2個検出されました
# [[1623  581  765  765]
#  [ 258  500  765  765]]
# [ex,ey] = 1623,581 [ew,eh] = 765,765
# [ex,ey] = 258,500 [ew,eh] = 765,765
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/211.JPG
# 目が1個検出されました
# [[122 461 666 666]]
# [ex,ey] = 122,461 [ew,eh] = 666,666
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/212.JPG
# 目が2個検出されました
# [[ 128  557  767  767]
#  [1553  494  825  825]]
# [ex,ey] = 128,557 [ew,eh] = 767,767
# [ex,ey] = 1553,494 [ew,eh] = 825,825
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/213.JPG
# 目が2個検出されました
# [[ 148  537  805  805]
#  [1525  475  800  800]]
# [ex,ey] = 148,537 [ew,eh] = 805,805
# [ex,ey] = 1525,475 [ew,eh] = 800,800
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/214.JPG
# 目が2個検出されました
# [[1507  448  713  713]
#  [ 104  441  744  744]]
# [ex,ey] = 1507,448 [ew,eh] = 713,713
# [ex,ey] = 104,441 [ew,eh] = 744,744
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/215.JPG
# 目が2個検出されました
# [[ 136  538  737  737]
#  [1569  480  867  867]]
# [ex,ey] = 136,538 [ew,eh] = 737,737
# [ex,ey] = 1569,480 [ew,eh] = 867,867
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/952.JPG
# 目が2個検出されました
# [[1518  450  873  873]
#  [ 148  512  856  856]]
# [ex,ey] = 1518,450 [ew,eh] = 873,873
# [ex,ey] = 148,512 [ew,eh] = 856,856
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/216.JPG
# 目が2個検出されました
# [[ 145  431  770  770]
#  [1563  484  780  780]]
# [ex,ey] = 145,431 [ew,eh] = 770,770
# [ex,ey] = 1563,484 [ew,eh] = 780,780
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/217.JPG
# 目が2個検出されました
# [[ 131  574  697  697]
#  [1532  465  781  781]]
# [ex,ey] = 131,574 [ew,eh] = 697,697
# [ex,ey] = 1532,465 [ew,eh] = 781,781
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/218.JPG
# 目が1個検出されました
# [[117 570 792 792]]
# [ex,ey] = 117,570 [ew,eh] = 792,792
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/953.JPG
# 目が2個検出されました
# [[1531  537  828  828]
#  [ 161  509  830  830]]
# [ex,ey] = 1531,537 [ew,eh] = 828,828
# [ex,ey] = 161,509 [ew,eh] = 830,830
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/219.JPG
# 目が2個検出されました
# [[ 280  605  801  801]
#  [1474  507  984  984]]
# [ex,ey] = 280,605 [ew,eh] = 801,801
# [ex,ey] = 1474,507 [ew,eh] = 984,984
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/954.JPG
# 目が2個検出されました
# [[ 213  554  770  770]
#  [1692  572  718  718]]
# [ex,ey] = 213,554 [ew,eh] = 770,770
# [ex,ey] = 1692,572 [ew,eh] = 718,718
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/220.JPG
# 目が2個検出されました
# [[1553  596  818  818]
#  [ 182  539  802  802]]
# [ex,ey] = 1553,596 [ew,eh] = 818,818
# [ex,ey] = 182,539 [ew,eh] = 802,802
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/221.JPG
# 目が2個検出されました
# [[ 143  537  772  772]
#  [1673  562  796  796]]
# [ex,ey] = 143,537 [ew,eh] = 772,772
# [ex,ey] = 1673,562 [ew,eh] = 796,796
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/222.JPG
# 目が2個検出されました
# [[ 135  531  729  729]
#  [1555  554  823  823]]
# [ex,ey] = 135,531 [ew,eh] = 729,729
# [ex,ey] = 1555,554 [ew,eh] = 823,823
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/223.JPG
# 目が2個検出されました
# [[ 145  454  767  767]
#  [1484  385  876  876]]
# [ex,ey] = 145,454 [ew,eh] = 767,767
# [ex,ey] = 1484,385 [ew,eh] = 876,876
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/224.JPG
# 目が2個検出されました
# [[ 111  415  822  822]
#  [1409  306 1034 1034]]
# [ex,ey] = 111,415 [ew,eh] = 822,822
# [ex,ey] = 1409,306 [ew,eh] = 1034,1034
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/225.JPG
# 目が2個検出されました
# [[1538  472  718  718]
#  [ 162  470  724  724]]
# [ex,ey] = 1538,472 [ew,eh] = 718,718
# [ex,ey] = 162,470 [ew,eh] = 724,724
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/226.JPG
# 目が2個検出されました
# [[1532  545  828  828]
#  [ 130  555  813  813]]
# [ex,ey] = 1532,545 [ew,eh] = 828,828
# [ex,ey] = 130,555 [ew,eh] = 813,813
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/227.JPG
# 目が2個検出されました
# [[ 118  482  774  774]
#  [1455  384  937  937]]
# [ex,ey] = 118,482 [ew,eh] = 774,774
# [ex,ey] = 1455,384 [ew,eh] = 937,937
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/228.JPG
# 目が2個検出されました
# [[ 101  449  721  721]
#  [1437  402  968  968]]
# [ex,ey] = 101,449 [ew,eh] = 721,721
# [ex,ey] = 1437,402 [ew,eh] = 968,968
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/229.JPG
# 目が2個検出されました
# [[1701  540  807  807]
#  [  88  550  796  796]]
# [ex,ey] = 1701,540 [ew,eh] = 807,807
# [ex,ey] = 88,550 [ew,eh] = 796,796
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/230.JPG
# 目が2個検出されました
# [[ 114  516  796  796]
#  [1574  461  915  915]]
# [ex,ey] = 114,516 [ew,eh] = 796,796
# [ex,ey] = 1574,461 [ew,eh] = 915,915
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/231.JPG
# 目が2個検出されました
# [[  51  493  845  845]
#  [1538  458  948  948]]
# [ex,ey] = 51,493 [ew,eh] = 845,845
# [ex,ey] = 1538,458 [ew,eh] = 948,948
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/232.JPG
# 目が2個検出されました
# [[1576  524  851  851]
#  [ 100  535  840  840]]
# [ex,ey] = 1576,524 [ew,eh] = 851,851
# [ex,ey] = 100,535 [ew,eh] = 840,840
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/233.JPG
# 目が2個検出されました
# [[ 211  497  799  799]
#  [1640  596  754  754]]
# [ex,ey] = 211,497 [ew,eh] = 799,799
# [ex,ey] = 1640,596 [ew,eh] = 754,754
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/955.JPG
# 目が2個検出されました
# [[ 178  520  800  800]
#  [1494  550  799  799]]
# [ex,ey] = 178,520 [ew,eh] = 800,800
# [ex,ey] = 1494,550 [ew,eh] = 799,799
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/234.JPG
# 目が2個検出されました
# [[ 107  574  803  803]
#  [1522  562  732  732]]
# [ex,ey] = 107,574 [ew,eh] = 803,803
# [ex,ey] = 1522,562 [ew,eh] = 732,732
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/235.JPG
# 目が2個検出されました
# [[1606  632  660  660]
#  [1396  479 1095 1095]]
# [ex,ey] = 1606,632 [ew,eh] = 660,660
# [ex,ey] = 1396,479 [ew,eh] = 1095,1095
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/236.JPG
# 目が2個検出されました
# [[ 180  529  774  774]
#  [1499  615  825  825]]
# [ex,ey] = 180,529 [ew,eh] = 774,774
# [ex,ey] = 1499,615 [ew,eh] = 825,825
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/252.JPG
# 目が2個検出されました
# [[ 148  514  746  746]
#  [1608  547  832  832]]
# [ex,ey] = 148,514 [ew,eh] = 746,746
# [ex,ey] = 1608,547 [ew,eh] = 832,832
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/253.JPG
# 目が2個検出されました
# [[ 152  438  898  898]
#  [1590  454  814  814]]
# [ex,ey] = 152,438 [ew,eh] = 898,898
# [ex,ey] = 1590,454 [ew,eh] = 814,814
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/254.JPG
# 目が2個検出されました
# [[ 173  482  686  686]
#  [1514  378  828  828]]
# [ex,ey] = 173,482 [ew,eh] = 686,686
# [ex,ey] = 1514,378 [ew,eh] = 828,828
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/958.JPG
# 目が2個検出されました
# [[ 275  622  684  684]
#  [1598  602  728  728]]
# [ex,ey] = 275,622 [ew,eh] = 684,684
# [ex,ey] = 1598,602 [ew,eh] = 728,728
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/255.JPG
# 目が3個検出されました
# [[ 118  415  764  764]
#  [1556  473  674  674]
#  [1373  279 1017 1017]]
# [ex,ey] = 118,415 [ew,eh] = 764,764
# [ex,ey] = 1556,473 [ew,eh] = 674,674
# [ex,ey] = 1373,279 [ew,eh] = 1017,1017
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/256.JPG
# 目が2個検出されました
# [[1614  590  803  803]
#  [ 123  569  760  760]]
# [ex,ey] = 1614,590 [ew,eh] = 803,803
# [ex,ey] = 123,569 [ew,eh] = 760,760
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/959.JPG
# 目が2個検出されました
# [[1544  583  795  795]
#  [ 136  540  787  787]]
# [ex,ey] = 1544,583 [ew,eh] = 795,795
# [ex,ey] = 136,540 [ew,eh] = 787,787
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/257.JPG
# 目が2個検出されました
# [[ 166  620  722  722]
#  [1578  635  764  764]]
# [ex,ey] = 166,620 [ew,eh] = 722,722
# [ex,ey] = 1578,635 [ew,eh] = 764,764
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/258.JPG
# 目が2個検出されました
# [[ 136  392  799  799]
#  [1577  420  843  843]]
# [ex,ey] = 136,392 [ew,eh] = 799,799
# [ex,ey] = 1577,420 [ew,eh] = 843,843
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/960.JPG
# 目が2個検出されました
# [[ 150  548  796  796]
#  [1583  492  819  819]]
# [ex,ey] = 150,548 [ew,eh] = 796,796
# [ex,ey] = 1583,492 [ew,eh] = 819,819
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/259.JPG
# 目が2個検出されました
# [[ 148  644  717  717]
#  [1544  565  812  812]]
# [ex,ey] = 148,644 [ew,eh] = 717,717
# [ex,ey] = 1544,565 [ew,eh] = 812,812
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/260.JPG
# 目が2個検出されました
# [[1558  539  783  783]
#  [ 172  539  735  735]]
# [ex,ey] = 1558,539 [ew,eh] = 783,783
# [ex,ey] = 172,539 [ew,eh] = 735,735
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/261.JPG
# 目が2個検出されました
# [[ 143  559  748  748]
#  [1562  550  826  826]]
# [ex,ey] = 143,559 [ew,eh] = 748,748
# [ex,ey] = 1562,550 [ew,eh] = 826,826
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/262.JPG
# 目が2個検出されました
# [[1568  519  816  816]
#  [ 263  569  797  797]]
# [ex,ey] = 1568,519 [ew,eh] = 816,816
# [ex,ey] = 263,569 [ew,eh] = 797,797
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/263.JPG
# 目が2個検出されました
# [[ 171  575  770  770]
#  [1522  544  810  810]]
# [ex,ey] = 171,575 [ew,eh] = 770,770
# [ex,ey] = 1522,544 [ew,eh] = 810,810
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/962.JPG
# 目が2個検出されました
# [[  63  424  787  787]
#  [1510  478  850  850]]
# [ex,ey] = 63,424 [ew,eh] = 787,787
# [ex,ey] = 1510,478 [ew,eh] = 850,850
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/278.JPG
# 目が2個検出されました
# [[1569  605  735  735]
#  [ 220  691  691  691]]
# [ex,ey] = 1569,605 [ew,eh] = 735,735
# [ex,ey] = 220,691 [ew,eh] = 691,691
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/279.JPG
# 目が2個検出されました
# [[ 103  561  784  784]
#  [1542  572  876  876]]
# [ex,ey] = 103,561 [ew,eh] = 784,784
# [ex,ey] = 1542,572 [ew,eh] = 876,876
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/280.JPG
# 目が2個検出されました
# [[1652  576  841  841]
#  [ 103  604  815  815]]
# [ex,ey] = 1652,576 [ew,eh] = 841,841
# [ex,ey] = 103,604 [ew,eh] = 815,815
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/963.JPG
# 目が2個検出されました
# [[ 184  537  798  798]
#  [1614  528  804  804]]
# [ex,ey] = 184,537 [ew,eh] = 798,798
# [ex,ey] = 1614,528 [ew,eh] = 804,804
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/281.JPG
# 目が1個検出されました
# [[364 505 568 568]]
# [ex,ey] = 364,505 [ew,eh] = 568,568
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/282.JPG
# 目が2個検出されました
# [[  67  505  926  926]
#  [1504  448  960  960]]
# [ex,ey] = 67,505 [ew,eh] = 926,926
# [ex,ey] = 1504,448 [ew,eh] = 960,960
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/284.JPG
# 目が2個検出されました
# [[ 116  511  817  817]
#  [1646  532  800  800]]
# [ex,ey] = 116,511 [ew,eh] = 817,817
# [ex,ey] = 1646,532 [ew,eh] = 800,800
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/283.JPG
# 目が2個検出されました
# [[1683  590  691  691]
#  [ 181  579  705  705]]
# [ex,ey] = 1683,590 [ew,eh] = 691,691
# [ex,ey] = 181,579 [ew,eh] = 705,705
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/285.JPG
# 目が2個検出されました
# [[ 197  650  723  723]
#  [1513  609  697  697]]
# [ex,ey] = 197,650 [ew,eh] = 723,723
# [ex,ey] = 1513,609 [ew,eh] = 697,697
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/286.JPG
# 目が1個検出されました
# [[ 71 441 770 770]]
# [ex,ey] = 71,441 [ew,eh] = 770,770
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/287.JPG
# 目が2個検出されました
# [[ 191  469  809  809]
#  [1559  472  826  826]]
# [ex,ey] = 191,469 [ew,eh] = 809,809
# [ex,ey] = 1559,472 [ew,eh] = 826,826
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/288.JPG
# 目が2個検出されました
# [[ 161  407  819  819]
#  [1537  427  785  785]]
# [ex,ey] = 161,407 [ew,eh] = 819,819
# [ex,ey] = 1537,427 [ew,eh] = 785,785
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/964.JPG
# 目が2個検出されました
# [[ 153  529  781  781]
#  [1504  579  799  799]]
# [ex,ey] = 153,529 [ew,eh] = 781,781
# [ex,ey] = 1504,579 [ew,eh] = 799,799
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/289.JPG
# 目が2個検出されました
# [[1539  547  855  855]
#  [ 107  554  828  828]]
# [ex,ey] = 1539,547 [ew,eh] = 855,855
# [ex,ey] = 107,554 [ew,eh] = 828,828
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/290.JPG
# 目が2個検出されました
# [[ 160  621  670  670]
#  [1623  613  740  740]]
# [ex,ey] = 160,621 [ew,eh] = 670,670
# [ex,ey] = 1623,613 [ew,eh] = 740,740
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/292.JPG
# 目が2個検出されました
# [[ 183  631  774  774]
#  [1578  686  781  781]]
# [ex,ey] = 183,631 [ew,eh] = 774,774
# [ex,ey] = 1578,686 [ew,eh] = 781,781
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/965.JPG
# 目が2個検出されました
# [[ 151  450  750  750]
#  [1554  455  737  737]]
# [ex,ey] = 151,450 [ew,eh] = 750,750
# [ex,ey] = 1554,455 [ew,eh] = 737,737
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/293.JPG
# 目が2個検出されました
# [[1590  553  777  777]
#  [ 200  535  778  778]]
# [ex,ey] = 1590,553 [ew,eh] = 777,777
# [ex,ey] = 200,535 [ew,eh] = 778,778
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/294.JPG
# 目が2個検出されました
# [[ 122  385  755  755]
#  [1507  365  926  926]]
# [ex,ey] = 122,385 [ew,eh] = 755,755
# [ex,ey] = 1507,365 [ew,eh] = 926,926
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/295.JPG
# 目が2個検出されました
# [[ 157  448  807  807]
#  [1548  496  749  749]]
# [ex,ey] = 157,448 [ew,eh] = 807,807
# [ex,ey] = 1548,496 [ew,eh] = 749,749
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/296.JPG
# 目が2個検出されました
# [[  98  386  838  838]
#  [1509  380  854  854]]
# [ex,ey] = 98,386 [ew,eh] = 838,838
# [ex,ey] = 1509,380 [ew,eh] = 854,854
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/297.JPG
# 目が2個検出されました
# [[ 123  466  797  797]
#  [1509  428  850  850]]
# [ex,ey] = 123,466 [ew,eh] = 797,797
# [ex,ey] = 1509,428 [ew,eh] = 850,850
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/298.JPG
# 目が2個検出されました
# [[ 237  636  738  738]
#  [1614  671  789  789]]
# [ex,ey] = 237,636 [ew,eh] = 738,738
# [ex,ey] = 1614,671 [ew,eh] = 789,789
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/299.JPG
# 目が2個検出されました
# [[1517  649  795  795]
#  [ 228  583  798  798]]
# [ex,ey] = 1517,649 [ew,eh] = 795,795
# [ex,ey] = 228,583 [ew,eh] = 798,798
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/300.JPG
# 目が2個検出されました
# [[ 166  409  775  775]
#  [1524  413  773  773]]
# [ex,ey] = 166,409 [ew,eh] = 775,775
# [ex,ey] = 1524,413 [ew,eh] = 773,773
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/301.JPG
# 目が2個検出されました
# [[ 191  426  749  749]
#  [1499  411  807  807]]
# [ex,ey] = 191,426 [ew,eh] = 749,749
# [ex,ey] = 1499,411 [ew,eh] = 807,807
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/303.JPG
# 目が2個検出されました
# [[ 141  585  742  742]
#  [1553  562  805  805]]
# [ex,ey] = 141,585 [ew,eh] = 742,742
# [ex,ey] = 1553,562 [ew,eh] = 805,805
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/302.JPG
# 目が2個検出されました
# [[ 190  482  784  784]
#  [1513  472  826  826]]
# [ex,ey] = 190,482 [ew,eh] = 784,784
# [ex,ey] = 1513,472 [ew,eh] = 826,826
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/304.JPG
# 目が2個検出されました
# [[ 135  523  853  853]
#  [1490  497  843  843]]
# [ex,ey] = 135,523 [ew,eh] = 853,853
# [ex,ey] = 1490,497 [ew,eh] = 843,843
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/305.JPG
# 目が2個検出されました
# [[ 171  572  798  798]
#  [1641  555  825  825]]
# [ex,ey] = 171,572 [ew,eh] = 798,798
# [ex,ey] = 1641,555 [ew,eh] = 825,825
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/306.JPG
# 目が2個検出されました
# [[ 138  414  753  753]
#  [1506  351  907  907]]
# [ex,ey] = 138,414 [ew,eh] = 753,753
# [ex,ey] = 1506,351 [ew,eh] = 907,907
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/323.JPG
# 目が2個検出されました
# [[  96  576  779  779]
#  [1616  516  886  886]]
# [ex,ey] = 96,576 [ew,eh] = 779,779
# [ex,ey] = 1616,516 [ew,eh] = 886,886
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/324.JPG
# 目が2個検出されました
# [[ 198  596  740  740]
#  [1591  549  832  832]]
# [ex,ey] = 198,596 [ew,eh] = 740,740
# [ex,ey] = 1591,549 [ew,eh] = 832,832
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/325.JPG
# 目が2個検出されました
# [[ 134  516  730  730]
#  [1497  515  800  800]]
# [ex,ey] = 134,516 [ew,eh] = 730,730
# [ex,ey] = 1497,515 [ew,eh] = 800,800
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/326.JPG
# 目が2個検出されました
# [[1605  609  685  685]
#  [ 224  578  714  714]]
# [ex,ey] = 1605,609 [ew,eh] = 685,685
# [ex,ey] = 224,578 [ew,eh] = 714,714
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/328.JPG
# 目が2個検出されました
# [[ 131  558  831  831]
#  [1620  542  809  809]]
# [ex,ey] = 131,558 [ew,eh] = 831,831
# [ex,ey] = 1620,542 [ew,eh] = 809,809
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/327.JPG
# 目が2個検出されました
# [[1610  504  885  885]
#  [ 190  494  920  920]]
# [ex,ey] = 1610,504 [ew,eh] = 885,885
# [ex,ey] = 190,494 [ew,eh] = 920,920
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/967.JPG
# 目が2個検出されました
# [[ 273  622  704  704]
#  [1560  601  683  683]]
# [ex,ey] = 273,622 [ew,eh] = 704,704
# [ex,ey] = 1560,601 [ew,eh] = 683,683
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/329.JPG
# 目が2個検出されました
# [[ 114  564  793  793]
#  [1594  614  819  819]]
# [ex,ey] = 114,564 [ew,eh] = 793,793
# [ex,ey] = 1594,614 [ew,eh] = 819,819
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/330.JPG
# 目が2個検出されました
# [[ 164  471  740  740]
#  [1535  453  803  803]]
# [ex,ey] = 164,471 [ew,eh] = 740,740
# [ex,ey] = 1535,453 [ew,eh] = 803,803
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/331.JPG
# 目が2個検出されました
# [[1472  502  833  833]
#  [ 140  605  754  754]]
# [ex,ey] = 1472,502 [ew,eh] = 833,833
# [ex,ey] = 140,605 [ew,eh] = 754,754
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/332.JPG
# 目が2個検出されました
# [[  89  636  720  720]
#  [1553  636  784  784]]
# [ex,ey] = 89,636 [ew,eh] = 720,720
# [ex,ey] = 1553,636 [ew,eh] = 784,784
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/968.JPG
# 目が2個検出されました
# [[ 115  571  680  680]
#  [1502  520  769  769]]
# [ex,ey] = 115,571 [ew,eh] = 680,680
# [ex,ey] = 1502,520 [ew,eh] = 769,769
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/333.JPG
# 目が2個検出されました
# [[ 170  428  730  730]
#  [1449  382  826  826]]
# [ex,ey] = 170,428 [ew,eh] = 730,730
# [ex,ey] = 1449,382 [ew,eh] = 826,826
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/334.JPG
# 目が2個検出されました
# [[1610  548  875  875]
#  [ 125  517  931  931]]
# [ex,ey] = 1610,548 [ew,eh] = 875,875
# [ex,ey] = 125,517 [ew,eh] = 931,931
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/335.JPG
# 目が2個検出されました
# [[ 133  584  801  801]
#  [1385  495  993  993]]
# [ex,ey] = 133,584 [ew,eh] = 801,801
# [ex,ey] = 1385,495 [ew,eh] = 993,993
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/336.JPG
# 目が2個検出されました
# [[  53  449  676  676]
#  [1491  377  889  889]]
# [ex,ey] = 53,449 [ew,eh] = 676,676
# [ex,ey] = 1491,377 [ew,eh] = 889,889
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/337.JPG
# 目が2個検出されました
# [[1574  608  690  690]
#  [ 182  601  763  763]]
# [ex,ey] = 1574,608 [ew,eh] = 690,690
# [ex,ey] = 182,601 [ew,eh] = 763,763
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/969.JPG
# 目が2個検出されました
# [[ 161  382  743  743]
#  [1533  333  865  865]]
# [ex,ey] = 161,382 [ew,eh] = 743,743
# [ex,ey] = 1533,333 [ew,eh] = 865,865
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/338.JPG
# 目が2個検出されました
# [[1507  369  868  868]
#  [  98  406  782  782]]
# [ex,ey] = 1507,369 [ew,eh] = 868,868
# [ex,ey] = 98,406 [ew,eh] = 782,782
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/339.JPG
# 目が2個検出されました
# [[ 108  551  738  738]
#  [1508  475  829  829]]
# [ex,ey] = 108,551 [ew,eh] = 738,738
# [ex,ey] = 1508,475 [ew,eh] = 829,829
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/340.JPG
# 目が2個検出されました
# [[ 230  531  766  766]
#  [1569  562  792  792]]
# [ex,ey] = 230,531 [ew,eh] = 766,766
# [ex,ey] = 1569,562 [ew,eh] = 792,792
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/341.JPG
# no eye detected
# ()
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/342.JPG
# 目が2個検出されました
# [[1569  594  795  795]
#  [ 142  579  791  791]]
# [ex,ey] = 1569,594 [ew,eh] = 795,795
# [ex,ey] = 142,579 [ew,eh] = 791,791
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/343.JPG
# 目が2個検出されました
# [[ 115  528  753  753]
#  [1525  503  818  818]]
# [ex,ey] = 115,528 [ew,eh] = 753,753
# [ex,ey] = 1525,503 [ew,eh] = 818,818
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/344.JPG
# 目が2個検出されました
# [[ 192  626  704  704]
#  [1619  554  768  768]]
# [ex,ey] = 192,626 [ew,eh] = 704,704
# [ex,ey] = 1619,554 [ew,eh] = 768,768
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/970.JPG
# 目が2個検出されました
# [[ 121  581  796  796]
#  [1513  581  876  876]]
# [ex,ey] = 121,581 [ew,eh] = 796,796
# [ex,ey] = 1513,581 [ew,eh] = 876,876
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/971.JPG
# 目が2個検出されました
# [[ 204  634  687  687]
#  [1523  618  788  788]]
# [ex,ey] = 204,634 [ew,eh] = 687,687
# [ex,ey] = 1523,618 [ew,eh] = 788,788
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/345.JPG
# 目が2個検出されました
# [[1580  582  797  797]
#  [ 117  618  836  836]]
# [ex,ey] = 1580,582 [ew,eh] = 797,797
# [ex,ey] = 117,618 [ew,eh] = 836,836
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/346.JPG
# 目が2個検出されました
# [[1565  305  787  787]
#  [ 153  286  740  740]]
# [ex,ey] = 1565,305 [ew,eh] = 787,787
# [ex,ey] = 153,286 [ew,eh] = 740,740
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/347.JPG
# 目が2個検出されました
# [[ 131  442  839  839]
#  [1597  441  771  771]]
# [ex,ey] = 131,442 [ew,eh] = 839,839
# [ex,ey] = 1597,441 [ew,eh] = 771,771
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/348.JPG
# 目が1個検出されました
# [[1554  574  708  708]]
# [ex,ey] = 1554,574 [ew,eh] = 708,708
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/349.JPG
# 目が2個検出されました
# [[ 122  483  727  727]
#  [1612  442  767  767]]
# [ex,ey] = 122,483 [ew,eh] = 727,727
# [ex,ey] = 1612,442 [ew,eh] = 767,767
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/350.JPG
# 目が2個検出されました
# [[1613  507  821  821]
#  [ 137  505  775  775]]
# [ex,ey] = 1613,507 [ew,eh] = 821,821
# [ex,ey] = 137,505 [ew,eh] = 775,775
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/935.JPG
# 目が2個検出されました
# [[1569  639  804  804]
#  [  88  649  863  863]]
# [ex,ey] = 1569,639 [ew,eh] = 804,804
# [ex,ey] = 88,649 [ew,eh] = 863,863
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/351.JPG
# 目が2個検出されました
# [[ 150  594  750  750]
#  [1569  535  832  832]]
# [ex,ey] = 150,594 [ew,eh] = 750,750
# [ex,ey] = 1569,535 [ew,eh] = 832,832
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/972.JPG
# 目が2個検出されました
# [[  96  432  779  779]
#  [1559  417  845  845]]
# [ex,ey] = 96,432 [ew,eh] = 779,779
# [ex,ey] = 1559,417 [ew,eh] = 845,845
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/353.JPG
# 目が2個検出されました
# [[1562  448  792  792]
#  [ 164  510  690  690]]
# [ex,ey] = 1562,448 [ew,eh] = 792,792
# [ex,ey] = 164,510 [ew,eh] = 690,690
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/352.JPG
# 目が2個検出されました
# [[ 104  438  630  630]
#  [1550  395  768  768]]
# [ex,ey] = 104,438 [ew,eh] = 630,630
# [ex,ey] = 1550,395 [ew,eh] = 768,768
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/354.JPG
# 目が2個検出されました
# [[ 182  417  749  749]
#  [1591  436  775  775]]
# [ex,ey] = 182,417 [ew,eh] = 749,749
# [ex,ey] = 1591,436 [ew,eh] = 775,775
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/355.JPG
# 目が1個検出されました
# [[1572  647  767  767]]
# [ex,ey] = 1572,647 [ew,eh] = 767,767
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/356.JPG
# 目が2個検出されました
# [[ 204  585  703  703]
#  [1523  525  812  812]]
# [ex,ey] = 204,585 [ew,eh] = 703,703
# [ex,ey] = 1523,525 [ew,eh] = 812,812
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/357.JPG
# 目が2個検出されました
# [[ 168  477  855  855]
#  [1697  542  761  761]]
# [ex,ey] = 168,477 [ew,eh] = 855,855
# [ex,ey] = 1697,542 [ew,eh] = 761,761
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/358.JPG
# 目が2個検出されました
# [[ 222  469  878  878]
#  [1595  543  897  897]]
# [ex,ey] = 222,469 [ew,eh] = 878,878
# [ex,ey] = 1595,543 [ew,eh] = 897,897
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/359.JPG
# 目が3個検出されました
# [[ 115  522  755  755]
#  [1416  496  944  944]
#  [ 365  534  845  845]]
# [ex,ey] = 115,522 [ew,eh] = 755,755
# [ex,ey] = 1416,496 [ew,eh] = 944,944
# [ex,ey] = 365,534 [ew,eh] = 845,845
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/360.JPG
# 目が2個検出されました
# [[1615  511  779  779]
#  [ 147  502  879  879]]
# [ex,ey] = 1615,511 [ew,eh] = 779,779
# [ex,ey] = 147,502 [ew,eh] = 879,879
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/361.JPG
# 目が2個検出されました
# [[ 300  651  606  606]
#  [1672  676  598  598]]
# [ex,ey] = 300,651 [ew,eh] = 606,606
# [ex,ey] = 1672,676 [ew,eh] = 598,598
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/362.JPG
# 目が2個検出されました
# [[1657  547  816  816]
#  [  47  564  679  679]]
# [ex,ey] = 1657,547 [ew,eh] = 816,816
# [ex,ey] = 47,564 [ew,eh] = 679,679
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/973.JPG
# 目が2個検出されました
# [[1655  550  811  811]
#  [ 104  538  759  759]]
# [ex,ey] = 1655,550 [ew,eh] = 811,811
# [ex,ey] = 104,538 [ew,eh] = 759,759
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/363.JPG
# 目が2個検出されました
# [[1571  460  947  947]
#  [  28  544  698  698]]
# [ex,ey] = 1571,460 [ew,eh] = 947,947
# [ex,ey] = 28,544 [ew,eh] = 698,698
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/364.JPG
# 目が2個検出されました
# [[ 124  335  773  773]
#  [1586  341  883  883]]
# [ex,ey] = 124,335 [ew,eh] = 773,773
# [ex,ey] = 1586,341 [ew,eh] = 883,883
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/974.JPG
# 目が2個検出されました
# [[1570  652  630  630]
#  [ 289  629  692  692]]
# [ex,ey] = 1570,652 [ew,eh] = 630,630
# [ex,ey] = 289,629 [ew,eh] = 692,692
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/365.JPG
# 目が2個検出されました
# [[  81  467  672  672]
#  [1518  322  870  870]]
# [ex,ey] = 81,467 [ew,eh] = 672,672
# [ex,ey] = 1518,322 [ew,eh] = 870,870
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/366.JPG
# 目が1個検出されました
# [[ 88 480 811 811]]
# [ex,ey] = 88,480 [ew,eh] = 811,811
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/367.JPG
# 目が2個検出されました
# [[ 160  536  766  766]
#  [1521  593  747  747]]
# [ex,ey] = 160,536 [ew,eh] = 766,766
# [ex,ey] = 1521,593 [ew,eh] = 747,747
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/368.JPG
# 目が2個検出されました
# [[ 202  691  694  694]
#  [1561  713  725  725]]
# [ex,ey] = 202,691 [ew,eh] = 694,694
# [ex,ey] = 1561,713 [ew,eh] = 725,725
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/369.JPG
# 目が2個検出されました
# [[ 147  548  733  733]
#  [1611  488  844  844]]
# [ex,ey] = 147,548 [ew,eh] = 733,733
# [ex,ey] = 1611,488 [ew,eh] = 844,844
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/370.JPG
# 目が1個検出されました
# [[1572  523  804  804]]
# [ex,ey] = 1572,523 [ew,eh] = 804,804
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/975.JPG
# 目が2個検出されました
# [[ 169  568  760  760]
#  [1564  497  809  809]]
# [ex,ey] = 169,568 [ew,eh] = 760,760
# [ex,ey] = 1564,497 [ew,eh] = 809,809
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/371.JPG
# 目が2個検出されました
# [[ 116  413  758  758]
#  [1507  368  908  908]]
# [ex,ey] = 116,413 [ew,eh] = 758,758
# [ex,ey] = 1507,368 [ew,eh] = 908,908
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/372.JPG
# 目が2個検出されました
# [[1608  494  856  856]
#  [ 130  533  798  798]]
# [ex,ey] = 1608,494 [ew,eh] = 856,856
# [ex,ey] = 130,533 [ew,eh] = 798,798
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/373.JPG
# 目が2個検出されました
# [[1672  715  730  730]
#  [ 185  752  730  730]]
# [ex,ey] = 1672,715 [ew,eh] = 730,730
# [ex,ey] = 185,752 [ew,eh] = 730,730
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/375.JPG
# 目が2個検出されました
# [[ 130  610  725  725]
#  [1569  571  809  809]]
# [ex,ey] = 130,610 [ew,eh] = 725,725
# [ex,ey] = 1569,571 [ew,eh] = 809,809
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/374.JPG
# 目が2個検出されました
# [[ 177  519  835  835]
#  [1589  595  834  834]]
# [ex,ey] = 177,519 [ew,eh] = 835,835
# [ex,ey] = 1589,595 [ew,eh] = 834,834
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/376.JPG
# 目が2個検出されました
# [[ 133  347  834  834]
#  [1481  344  818  818]]
# [ex,ey] = 133,347 [ew,eh] = 834,834
# [ex,ey] = 1481,344 [ew,eh] = 818,818
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/377.JPG
# 目が2個検出されました
# [[1528  392  848  848]
#  [ 121  436  786  786]]
# [ex,ey] = 1528,392 [ew,eh] = 848,848
# [ex,ey] = 121,436 [ew,eh] = 786,786
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/378.JPG
# 目が2個検出されました
# [[ 108  462  784  784]
# ...
# 目が2個検出されました
# [[ 160  549  731  731]
#  [1531  528  784  784]]
# [ex,ey] = 160,549 [ew,eh] = 731,731
# [ex,ey] = 1531,528 [ew,eh] = 784,784
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/876.JPG
# 目が2個検出されました
# [[ 162  639  761  761]
#  [1611  615  802  802]]
# [ex,ey] = 162,639 [ew,eh] = 761,761
# [ex,ey] = 1611,615 [ew,eh] = 802,802
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/877.JPG
# 目が2個検出されました
# [[ 149  367  849  849]
#  [1582  414  848  848]]
# [ex,ey] = 149,367 [ew,eh] = 849,849
# [ex,ey] = 1582,414 [ew,eh] = 848,848
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/878.JPG
# 目が2個検出されました
# [[ 177  594  745  745]
#  [1539  576  714  714]]
# [ex,ey] = 177,594 [ew,eh] = 745,745
# [ex,ey] = 1539,576 [ew,eh] = 714,714
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/879.JPG
# 目が2個検出されました
# [[ 206  445  794  794]
#  [1558  438  852  852]]
# [ex,ey] = 206,445 [ew,eh] = 794,794
# [ex,ey] = 1558,438 [ew,eh] = 852,852
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/1030.JPG
# 目が1個検出されました
# [[ 73 860 416 416]]
# [ex,ey] = 73,860 [ew,eh] = 416,416
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/1031.JPG
# 目が2個検出されました
# [[1602  454  653  653]
#  [ 140  381  768  768]]
# [ex,ey] = 1602,454 [ew,eh] = 653,653
# [ex,ey] = 140,381 [ew,eh] = 768,768
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/883.JPG
# 目が2個検出されました
# [[1522  335  806  806]
#  [ 139  385  791  791]]
# [ex,ey] = 1522,335 [ew,eh] = 806,806
# [ex,ey] = 139,385 [ew,eh] = 791,791
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/884.JPG
# 目が2個検出されました
# [[1558  568  734  734]
#  [ 207  649  711  711]]
# [ex,ey] = 1558,568 [ew,eh] = 734,734
# [ex,ey] = 207,649 [ew,eh] = 711,711
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/886.JPG
# 目が2個検出されました
# [[ 146  449  733  733]
#  [1525  486  791  791]]
# [ex,ey] = 146,449 [ew,eh] = 733,733
# [ex,ey] = 1525,486 [ew,eh] = 791,791
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/887.JPG
# 目が2個検出されました
# [[ 159  468  833  833]
#  [1576  478  817  817]]
# [ex,ey] = 159,468 [ew,eh] = 833,833
# [ex,ey] = 1576,478 [ew,eh] = 817,817
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/885.JPG
# 目が2個検出されました
# [[  83  364  811  811]
#  [1568  412  796  796]]
# [ex,ey] = 83,364 [ew,eh] = 811,811
# [ex,ey] = 1568,412 [ew,eh] = 796,796
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/888.JPG
# 目が2個検出されました
# [[1548  599  775  775]
#  [ 122  610  762  762]]
# [ex,ey] = 1548,599 [ew,eh] = 775,775
# [ex,ey] = 122,610 [ew,eh] = 762,762
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/889.JPG
# 目が2個検出されました
# [[1626  480  783  783]
#  [ 121  575  752  752]]
# [ex,ey] = 1626,480 [ew,eh] = 783,783
# [ex,ey] = 121,575 [ew,eh] = 752,752
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/890.JPG
# 目が2個検出されました
# [[  82  507  631  631]
#  [1454  472  822  822]]
# [ex,ey] = 82,507 [ew,eh] = 631,631
# [ex,ey] = 1454,472 [ew,eh] = 822,822
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/891.JPG
# 目が2個検出されました
# [[ 191  579  807  807]
#  [1535  566  848  848]]
# [ex,ey] = 191,579 [ew,eh] = 807,807
# [ex,ey] = 1535,566 [ew,eh] = 848,848
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/892.JPG
# 目が2個検出されました
# [[  92  634  710  710]
#  [1583  646  756  756]]
# [ex,ey] = 92,634 [ew,eh] = 710,710
# [ex,ey] = 1583,646 [ew,eh] = 756,756
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/893.JPG
# 目が1個検出されました
# [[140 626 670 670]]
# [ex,ey] = 140,626 [ew,eh] = 670,670
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/894.JPG
# 目が2個検出されました
# [[ 160  516  845  845]
#  [1641  490  797  797]]
# [ex,ey] = 160,516 [ew,eh] = 845,845
# [ex,ey] = 1641,490 [ew,eh] = 797,797
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/896.JPG
# 目が2個検出されました
# [[1605  418  775  775]
#  [ 128  426  808  808]]
# [ex,ey] = 1605,418 [ew,eh] = 775,775
# [ex,ey] = 128,426 [ew,eh] = 808,808
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/895.JPG
# 目が1個検出されました
# [[1758  576  573  573]]
# [ex,ey] = 1758,576 [ew,eh] = 573,573
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/897.JPG
# 目が2個検出されました
# [[ 189  472  779  779]
#  [1602  566  695  695]]
# [ex,ey] = 189,472 [ew,eh] = 779,779
# [ex,ey] = 1602,566 [ew,eh] = 695,695
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/898.JPG
# 目が2個検出されました
# [[ 202  420  806  806]
#  [1629  487  822  822]]
# [ex,ey] = 202,420 [ew,eh] = 806,806
# [ex,ey] = 1629,487 [ew,eh] = 822,822
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/899.JPG
# 目が2個検出されました
# [[ 187  658  799  799]
#  [1543  609  824  824]]
# [ex,ey] = 187,658 [ew,eh] = 799,799
# [ex,ey] = 1543,609 [ew,eh] = 824,824
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/900.JPG
# 目が2個検出されました
# [[ 221  628  769  769]
#  [1606  625  772  772]]
# [ex,ey] = 221,628 [ew,eh] = 769,769
# [ex,ey] = 1606,625 [ew,eh] = 772,772
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/901.JPG
# 目が2個検出されました
# [[1550  453  846  846]
#  [ 138  502  858  858]]
# [ex,ey] = 1550,453 [ew,eh] = 846,846
# [ex,ey] = 138,502 [ew,eh] = 858,858
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/902.JPG
# 目が2個検出されました
# [[ 132  355  801  801]
#  [1633  496  767  767]]
# [ex,ey] = 132,355 [ew,eh] = 801,801
# [ex,ey] = 1633,496 [ew,eh] = 767,767
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/903.JPG
# 目が2個検出されました
# [[1502  328  902  902]
#  [ 117  385  840  840]]
# [ex,ey] = 1502,328 [ew,eh] = 902,902
# [ex,ey] = 117,385 [ew,eh] = 840,840
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/904.JPG
# 目が2個検出されました
# [[1589  588  784  784]
#  [ 120  550  809  809]]
# [ex,ey] = 1589,588 [ew,eh] = 784,784
# [ex,ey] = 120,550 [ew,eh] = 809,809
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/905.JPG
# 目が2個検出されました
# [[ 142  622  774  774]
#  [1591  601  825  825]]
# [ex,ey] = 142,622 [ew,eh] = 774,774
# [ex,ey] = 1591,601 [ew,eh] = 825,825
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/906.JPG
# 目が2個検出されました
# [[1567  573  756  756]
#  [ 186  554  748  748]]
# [ex,ey] = 1567,573 [ew,eh] = 756,756
# [ex,ey] = 186,554 [ew,eh] = 748,748
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/907.JPG
# 目が2個検出されました
# [[1585  608  757  757]
#  [ 229  544  726  726]]
# [ex,ey] = 1585,608 [ew,eh] = 757,757
# [ex,ey] = 229,544 [ew,eh] = 726,726
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/908.JPG
# 目が2個検出されました
# [[ 334  507  757  757]
#  [1634  507  770  770]]
# [ex,ey] = 334,507 [ew,eh] = 757,757
# [ex,ey] = 1634,507 [ew,eh] = 770,770
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/909.JPG
# 目が2個検出されました
# [[ 127  609  715  715]
#  [1561  582  793  793]]
# [ex,ey] = 127,609 [ew,eh] = 715,715
# [ex,ey] = 1561,582 [ew,eh] = 793,793
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/910.JPG
# 目が2個検出されました
# [[1467  650  910  910]
#  [ 116  637  870  870]]
# [ex,ey] = 1467,650 [ew,eh] = 910,910
# [ex,ey] = 116,637 [ew,eh] = 870,870
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/911.JPG
# 目が2個検出されました
# [[1632  557  838  838]
#  [  65  568  765  765]]
# [ex,ey] = 1632,557 [ew,eh] = 838,838
# [ex,ey] = 65,568 [ew,eh] = 765,765
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/912.JPG
# 目が2個検出されました
# [[1583  664  718  718]
#  [ 292  705  752  752]]
# [ex,ey] = 1583,664 [ew,eh] = 718,718
# [ex,ey] = 292,705 [ew,eh] = 752,752
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/913.JPG
# 目が2個検出されました
# [[1612  535  812  812]
#  [ 177  604  725  725]]
# [ex,ey] = 1612,535 [ew,eh] = 812,812
# [ex,ey] = 177,604 [ew,eh] = 725,725
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/914.JPG
# 目が2個検出されました
# [[ 187  509  721  721]
#  [1486  578  776  776]]
# [ex,ey] = 187,509 [ew,eh] = 721,721
# [ex,ey] = 1486,578 [ew,eh] = 776,776
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/915.JPG
# 目が2個検出されました
# [[ 237  437  685  685]
#  [1619  463  779  779]]
# [ex,ey] = 237,437 [ew,eh] = 685,685
# [ex,ey] = 1619,463 [ew,eh] = 779,779
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/916.JPG
# 目が3個検出されました
# [[ 241  631  761  761]
#  [1430  682  938  938]
#  [1645  819  512  512]]
# [ex,ey] = 241,631 [ew,eh] = 761,761
# [ex,ey] = 1430,682 [ew,eh] = 938,938
# [ex,ey] = 1645,819 [ew,eh] = 512,512
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/918.JPG
# 目が2個検出されました
# [[1542  426  749  749]
#  [  96  464  729  729]]
# [ex,ey] = 1542,426 [ew,eh] = 749,749
# [ex,ey] = 96,464 [ew,eh] = 729,729
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/919.JPG
# 目が2個検出されました
# [[ 116  614  826  826]
#  [1479  645  848  848]]
# [ex,ey] = 116,614 [ew,eh] = 826,826
# [ex,ey] = 1479,645 [ew,eh] = 848,848
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/917.JPG
# 目が2個検出されました
# [[ 194  570  705  705]
#  [1555  589  709  709]]
# [ex,ey] = 194,570 [ew,eh] = 705,705
# [ex,ey] = 1555,589 [ew,eh] = 709,709
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/920.JPG
# 目が2個検出されました
# [[1483  343  772  772]
#  [ 117  379  782  782]]
# [ex,ey] = 1483,343 [ew,eh] = 772,772
# [ex,ey] = 117,379 [ew,eh] = 782,782
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/921.JPG
# 目が2個検出されました
# [[ 191  506  699  699]
#  [1692  510  727  727]]
# [ex,ey] = 191,506 [ew,eh] = 699,699
# [ex,ey] = 1692,510 [ew,eh] = 727,727
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/922.JPG
# 目が2個検出されました
# [[ 164  486  717  717]
#  [1610  454  787  787]]
# [ex,ey] = 164,486 [ew,eh] = 717,717
# [ex,ey] = 1610,454 [ew,eh] = 787,787
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/923.JPG
# 目が2個検出されました
# [[ 230  600  748  748]
#  [1560  577  786  786]]
# [ex,ey] = 230,600 [ew,eh] = 748,748
# [ex,ey] = 1560,577 [ew,eh] = 786,786
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/924.JPG
# 目が2個検出されました
# [[ 118  518  865  865]
#  [1606  499  886  886]]
# [ex,ey] = 118,518 [ew,eh] = 865,865
# [ex,ey] = 1606,499 [ew,eh] = 886,886
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/925.JPG
# 目が3個検出されました
# [[ 279  642  444  444]
#  [  62  358 1046 1046]
#  [1546  462  909  909]]
# [ex,ey] = 279,642 [ew,eh] = 444,444
# [ex,ey] = 62,358 [ew,eh] = 1046,1046
# [ex,ey] = 1546,462 [ew,eh] = 909,909
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/926.JPG
# 目が2個検出されました
# [[1544  648  726  726]
#  [ 150  611  729  729]]
# [ex,ey] = 1544,648 [ew,eh] = 726,726
# [ex,ey] = 150,611 [ew,eh] = 729,729
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/927.JPG
# 目が2個検出されました
# [[ 152  663  649  649]
#  [1624  608  813  813]]
# [ex,ey] = 152,663 [ew,eh] = 649,649
# [ex,ey] = 1624,608 [ew,eh] = 813,813
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/928.JPG
# 目が2個検出されました
# [[ 189  345  875  875]
#  [1626  464  737  737]]
# [ex,ey] = 189,345 [ew,eh] = 875,875
# [ex,ey] = 1626,464 [ew,eh] = 737,737
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/929.JPG
# 目が2個検出されました
# [[ 140  498  790  790]
#  [1584  486  842  842]]
# [ex,ey] = 140,498 [ew,eh] = 790,790
# [ex,ey] = 1584,486 [ew,eh] = 842,842
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/930.JPG
# 目が2個検出されました
# [[ 192  553  803  803]
#  [1717  631  669  669]]
# [ex,ey] = 192,553 [ew,eh] = 803,803
# [ex,ey] = 1717,631 [ew,eh] = 669,669
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/931.JPG
# 目が2個検出されました
# [[ 174  633  731  731]
#  [1577  626  762  762]]
# [ex,ey] = 174,633 [ew,eh] = 731,731
# [ex,ey] = 1577,626 [ew,eh] = 762,762
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/932.JPG
# 目が2個検出されました
# [[ 127  384  756  756]
#  [1552  331  810  810]]
# [ex,ey] = 127,384 [ew,eh] = 756,756
# [ex,ey] = 1552,331 [ew,eh] = 810,810
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/933.JPG
# 目が2個検出されました
# [[1772  691  618  618]
#  [ 303  665  677  677]]
# [ex,ey] = 1772,691 [ew,eh] = 618,618
# [ex,ey] = 303,665 [ew,eh] = 677,677
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/934.JPG
# 目が2個検出されました
# [[1581  569  833  833]
#  [ 127  576  737  737]]
# [ex,ey] = 1581,569 [ew,eh] = 833,833
# [ex,ey] = 127,576 [ew,eh] = 737,737
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/3.JPG
# 目が2個検出されました
# [[ 216  560  837  837]
#  [1476  537  890  890]]
# [ex,ey] = 216,560 [ew,eh] = 837,837
# [ex,ey] = 1476,537 [ew,eh] = 890,890
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/4.JPG
# 目が2個検出されました
# [[ 183  392  803  803]
#  [1508  442  743  743]]
# [ex,ey] = 183,392 [ew,eh] = 803,803
# [ex,ey] = 1508,442 [ew,eh] = 743,743
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/5.JPG
# 目が2個検出されました
# [[1775  683  621  621]
#  [ 168  624  688  688]]
# [ex,ey] = 1775,683 [ew,eh] = 621,621
# [ex,ey] = 168,624 [ew,eh] = 688,688
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/6.JPG
# 目が2個検出されました
# [[ 146  587  745  745]
#  [1530  582  760  760]]
# [ex,ey] = 146,587 [ew,eh] = 745,745
# [ex,ey] = 1530,582 [ew,eh] = 760,760
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/7.JPG
# 目が2個検出されました
# [[ 165  430  759  759]
#  [1588  469  737  737]]
# [ex,ey] = 165,430 [ew,eh] = 759,759
# [ex,ey] = 1588,469 [ew,eh] = 737,737
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/8.JPG
# 目が2個検出されました
# [[  66  572  761  761]
#  [1616  485  856  856]]
# [ex,ey] = 66,572 [ew,eh] = 761,761
# [ex,ey] = 1616,485 [ew,eh] = 856,856
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/9.JPG
# 目が2個検出されました
# [[ 126  622  884  884]
#  [1619  646  806  806]]
# [ex,ey] = 126,622 [ew,eh] = 884,884
# [ex,ey] = 1619,646 [ew,eh] = 806,806
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/10.JPG
# 目が2個検出されました
# [[1576  426  811  811]
#  [ 211  461  829  829]]
# [ex,ey] = 1576,426 [ew,eh] = 811,811
# [ex,ey] = 211,461 [ew,eh] = 829,829
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/11.JPG
# 目が2個検出されました
# [[ 203  503  694  694]
#  [1587  444  779  779]]
# [ex,ey] = 203,503 [ew,eh] = 694,694
# [ex,ey] = 1587,444 [ew,eh] = 779,779
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/12.JPG
# 目が2個検出されました
# [[ 316  595  670  670]
#  [1666  536  808  808]]
# [ex,ey] = 316,595 [ew,eh] = 670,670
# [ex,ey] = 1666,536 [ew,eh] = 808,808
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/13.JPG
# 目が2個検出されました
# [[ 205  524  754  754]
#  [1572  511  786  786]]
# [ex,ey] = 205,524 [ew,eh] = 754,754
# [ex,ey] = 1572,511 [ew,eh] = 786,786
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/14.JPG
# 目が2個検出されました
# [[1543  657  774  774]
#  [ 236  568  835  835]]
# [ex,ey] = 1543,657 [ew,eh] = 774,774
# [ex,ey] = 236,568 [ew,eh] = 835,835
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/15.JPG
# 目が2個検出されました
# [[ 198  453  699  699]
#  [1533  422  767  767]]
# [ex,ey] = 198,453 [ew,eh] = 699,699
# [ex,ey] = 1533,422 [ew,eh] = 767,767
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/16.JPG
# 目が2個検出されました
# [[1548  609  780  780]
#  [ 178  652  736  736]]
# [ex,ey] = 1548,609 [ew,eh] = 780,780
# [ex,ey] = 178,652 [ew,eh] = 736,736
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/17.JPG
# 目が2個検出されました
# [[ 216  436  777  777]
#  [1515  468  749  749]]
# [ex,ey] = 216,436 [ew,eh] = 777,777
# [ex,ey] = 1515,468 [ew,eh] = 749,749
# image path =  /content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset/18.JPG
# 目が1個検出されました
# [[133 417 841 841]]
# [ex,ey] = 133,417 [ew,eh] = 841,841
# Process done!!
# elapsed_time:129.4180929660797[sec]
